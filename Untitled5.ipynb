# %%
import pandas as pd

# %%
df=pd.read_excel('Final_Dataset.xlsx')

# %%
df.head(100)
# Out:
#     Unnamed: 0  Customer_Id  Product_Id       Review_ID Product_Category  \
# 0            0      3575256  B00RFM5984  R1BP7IWCZE6FQY           Beauty
# 1            1     45940035  B00L83AI2S   RKHOFMRPS9OIQ           Beauty
# 2            2     21057750  B00NW3O83C   RCFGZCIQOB29J           Sports
# 3            3     46444139  B00GABH5A6  R1RF0L40KNRM1V             Home
# 4            4     22816847  B00UKOD896   ROSQVAVJNA83W           Sports
# ..         ...          ...         ...             ...              ...
# 95          95     22725460  B00HLBPU06  R1Q99YEVDGA6YB           Sports
# 96          96     47235630  B00UA2A0XK  R3290PR2ZXZ16M           Beauty
# 97          97     45844341  B00TA88HM6  R1IHH3EDKSA83L           Sports
# 98          98     32599885  B00TRPQP62  R1PUSSFHJHDDVA          Grocery
# 99          99     10551926  B00VJGXV6O  R2BP4018Q6U1XJ     Pet Products
#
#     Star_Rating  Helpful_Votes  Total_Votes  \
# 0             5              1            4
# 1             5             33           36
# 2             5              0            0
# 3             1              0            3
# 4             4              0            0
# ..          ...            ...          ...
# 95            5              0            0
# 96            3              0            0
# 97            4              0            0
# 98            5              2            2
# 99            5              3            3
#
#                                       Review_Headline  \
# 0                                  beauty on a budget
# 1                A Very Good Product for Skin Pickers
# 2                                          Five Stars
# 3   Not happy.  No instructions or even a name of ...
# 4                         Great Quality for the Price
# ..                                                ...
# 95                                              great
# 96                 I like the container with the pump
# 97                                 Love my Fitbit One
# 98                                         Five Stars
# 99  Great collar, would highly recommend this prod...
#
#                                           Review_Body Review_Date  \
# 0   love these brushes and very soft foundation br...  2015-05-29
# 1   I don't suffer from acne. However I suffer fro...  2015-04-04
# 2                                       Great socks!!  2015-07-20
# 3   I got absolutely no instructions with my vinyl...  2015-08-29
# 4   These pliers are a great find for fishermen. T...  2015-07-09
# ..                                                ...         ...
# 95                                     Kids loved it.  2015-04-06
# 96  I like the container with the pump.  Worked to...  2015-07-08
# 97  I'm looking forward to using this but haven't ...  2015-04-01
# 98  I found it Very Refreshing on hot North Caroli...  2015-05-06
# 99  We just received the collar on Saturday aftern...  2015-07-20
#
#     Helpfulness_Index  Index_Avg  Activity  Reputation  Helpfulness_Label  \
# 0            0.250000   0.125000         5    0.625000                  0
# 1            0.916667   0.916667         1    0.916667                  1
# 2            0.000000   0.000000         6    0.000000                  0
# 3            0.000000   0.000000         8    0.000000                  0
# 4            0.000000   0.000000         1    0.000000                  0
# ..                ...        ...       ...         ...                ...
# 95           0.000000   0.000000         2    0.000000                  0
# 96           0.000000   0.000000         4    0.000000                  0
# 97           0.000000   0.000000         7    0.000000                  0
# 98           1.000000   1.000000         2    2.000000                  1
# 99           1.000000   1.000000         1    1.000000                  1
#
#     Text_Length  Order  Time Interval
# 0            60     45              1
# 1           168     28              3
# 2             2      4             12
# 3           125      1              7
# 4            69      6              0
# ..          ...    ...            ...
# 95            3     22              3
# 96           20     94              0
# 97           29     20              2
# 98           15     27              2
# 99          306    126              1
#
# [100 rows x 19 columns]

# %%
df['Helpfulness_Label']
# Out:
# 0         0
# 1         1
# 2         0
# 3         0
# 4         0
#          ..
# 247710    0
# 247711    1
# 247712    1
# 247713    0
# 247714    0
# Name: Helpfulness_Label, Length: 247715, dtype: int64

# %%
import warnings;
warnings.filterwarnings('ignore')

# %%
from gensim.models import Word2Vec 
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

# %%
df['Review_Body']=df['Review_Body'].astype(str)

# %%
import re
cleaned_review_body=df['Review_Body'].str.replace('[^a-zA-Z]'," ")

# %%
cleaned_review=cleaned_review_body.str.split()

# %%
cleaned_review
# Out:
# 0         [love, these, brushes, and, very, soft, founda...
# 1         [I, don, t, suffer, from, acne, However, I, su...
# 2                                            [Great, socks]
# 3         [I, got, absolutely, no, instructions, with, m...
# 4         [These, pliers, are, a, great, find, for, fish...
#                                 ...
# 247710                              [Product, as, promised]
# 247711    [Locks, securely, but, the, combo, is, horribl...
# 247712    [i, totally, LOVE, it, at, last, i, can, enjoy...
# 247713    [Amazing, smell, Arrived, before, ETA, Really,...
# 247714    [Fits, over, mat, perfectly, No, slipping, on,...
# Name: Review_Body, Length: 247715, dtype: object

# %%
import nltk

# %%
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ameli\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')

# %%
cleaned_review=cleaned_review.apply(lambda x: [word for word in x if word not in stop_words])

# %%
#from nltk.stem import SnowballStemmer

# %%
#stemmer= SnowballStemmer('english')

# %%
#cleaned_review_body=cleaned_review_body.apply(lambda x: [stemmer.stem(word) for word in x ])

# %%
cleaned_review=cleaned_review.apply(lambda x: [word for word in x if len(word)>3 and len(word)<12])

# %%
cleaned_review
# Out:
# 0         [love, brushes, soft, foundation, brush, washe...
# 1         [suffer, acne, however, suffer, compulsive, sk...
# 2                                            [great, socks]
# 3         [absolutely, vinyl, assumed, heat, vinyl, coul...
# 4         [these, pliers, great, find, fishermen, they, ...
#                                 ...
# 247710                                  [product, promised]
# 247711    [locks, securely, combo, horrible, bought, mou...
# 247712    [totally, love, last, enjoy, coffee, worry, an...
# 247713    [amazing, smell, arrived, really, satisfied, p...
# 247714    [fits, perfectly, slipping, sweat, great, prod...
# Name: Review_Body, Length: 247715, dtype: object

# %%
#cleaned_review_body.apply(lambda x: [word.replace('\i$', 'y') for word in x])
# Out:
# 0         [love, these, brush, veri, soft, foundat, brus...
# 1         [suffer, from, howev, suffer, from, compuls, s...
# 2                                             [great, sock]
# 3         [absolut, instruct, with, vinyl, assum, heat, ...
# 4         [these, plier, great, find, fishermen, they, e...
#                                 ...
# 247710                                    [product, promis]
# 247711    [lock, secur, combo, horribl, bought, this, mo...
# 247712    [total, love, last, enjoy, coffe, worri, about...
# 247713    [amaz, smell, arriv, befor, realli, satisfi, p...
# 247714    [over, perfect, slip, your, sweat, great, prod...
# Name: Review_Body, Length: 247715, dtype: object

# %%
#model = Word2Vec(cleaned_review_body, min_count=2,size= 100,workers=3, window =3, sg = 0)

# %%
import gensim.downloader as api

# %%
model_1 = api.load("glove-twitter-100")

# %%
model_1.vector_size
# Out:
# 100

# %%
reviews=[sen for sen in df['Review_Body']]

# %%
reviews=" ".join(reviews)

# %%
from nltk.tokenize import word_tokenize

cleaned_review=df['Review_Body'].apply(word_tokenize)

# %%
cleaned_review=cleaned_review.apply(lambda x: [word.lower() for word in x])

# %%
cleaned_review=cleaned_review.apply(lambda x:[word for word in x if len(word)>3 and len(word)<12])

# %%
cleaned_review=cleaned_review.apply(lambda x:[word for word in x if word not in
stop_words])

# %%
vector_list = [model_1[word] for word in tokens if word in model_1.wv.vocab]

# %%
words_list = [word for word in tokens if word in model_1.vocab]

# %%
word_vec_zip = zip(words_list, vector_list)

# %%
word_vec_dict = dict(word_vec_zip)

# %%
df_vectorized_w2vec = pd.DataFrame.from_dict(word_vec_dict, orient='index')

# %%
df_vectorized_w2vec.to_csv('vectoriezed_text.csv')

# %%
df_vectorized_w2vec=pd.read_csv("vectoriezed_text.csv")

# %%
df_vectorized_w2vec=df_vectorized_w2vec.iloc[:,1:]

# %%
from sklearn.manifold import TSNE

tsne = TSNE(n_components = 2, init = 'random', random_state = 10, perplexity = 100)

# %%
tsne_df = tsne.fit_transform(df_vectorized_w2vec)

# %%
tsne_df=pd.DataFrame(tsne_df)
tsne_df.to_csv("tnse_df.csv")

# %%
def document_vector(word2vec_model, doc):
    
    doc = [word for word in doc if word in model_1.vocab]
    return np.mean(model_1[doc], axis=0)

# %%
def preprocess(text):
    text = text.lower()
    doc = word_tokenize(text)
    doc = [word for word in doc if word not in stop_words]
    doc = [word for word in doc if word.isalpha()] 
    #doc = [word for word in doc if len(word)>4 and len(word)<12]
    return doc

# %%
def has_vector_representation(word2vec_model, doc):
    """check if at least one word of the document is in the
    word2vec dictionary"""
    return not all(word not in word2vec_model.vocab for word in doc)

# %%
def filter_docs(corpus, texts, condition_on_doc):
    
    number_of_docs = len(corpus)

    if texts is not None:
        texts = [text for (text, doc) in zip(texts, corpus)
                 if condition_on_doc(doc)]

    corpus = [doc for doc in corpus if condition_on_doc(doc)]

    print("{} docs removed".format(number_of_docs - len(corpus)))

    return (corpus, texts,index)

# %%
review_list_1=[doc for doc in df['Review_Body']]

# %%
review_list=[doc for doc in df['Review_Body']]

# %%
cleaned_review_body_1=[preprocess(i) for i in review_list_1]

# %%
def process_text(text):
    #text = text.lower()
    doc = word_tokenize(text)
    doc = [word for word in doc if word not in stop_words]
    doc = [word.lower() for word in doc]
    doc = [word for word in doc if word.isalpha()] 
    doc = [word for word in doc if len(word)>3 and len(word)<12]
    return doc

# %%
cleaned_review=[process_text(i) for i in df['Review_Body']]

# %%
cleaned_review_body_2=[preprocess(i) for i in review_list_1]

# %%
cleaned_review_body_1, review_list_1 = filter_docs(cleaned_review_body_1, review_list_1, lambda doc: has_vector_representation(model_1, doc))
# Out:
# 654 docs removed

# %%
len(review_list)
# Out:
# 247715

# %%
cleaned_review_body_1, review_list_1 = filter_docs(cleaned_review_body_1, review_list_1, lambda doc: (len(doc) != 0))
# Out:
# 0 docs removed

# %%
from nltk.tokenize.treebank import TreebankWordDetokenizer

# %%
detokenized_1=[TreebankWordDetokenizer().detokenize(word) for word in cleaned_review_body_1]

# %%
detokenized_2=[TreebankWordDetokenizer().detokenize(word) for word in cleaned_review_body_2]

# %%
detokenized_removed=pd.DataFrame(detokenized_1)

# %%
detokenized_original=pd.DataFrame(detokenized_2)

# %%
detokenized_removed.shape
# Out:
# (247061, 1)

# %%
import numpy as np
x = []
for doc in cleaned_review_body_1: 
    x.append(document_vector(model_1, doc))
    
X = np.array(x)

# %%
pd.DataFrame(X)
# Out:
#               0         1         2         3         4         5         6   \
# 0      -0.335593 -0.183956  0.084420  0.182747  0.095725  0.084332  0.139901
# 1       0.057332 -0.145008 -0.077507  0.099913 -0.001726  0.239505  0.195212
# 2       0.240265 -0.449910  0.255430  0.216341  0.294065  0.479560  0.316960
# 3       0.102460  0.034363 -0.035178 -0.003887  0.102370  0.165402  0.198205
# 4       0.122722 -0.046204  0.000785 -0.031691 -0.045783 -0.017736  0.235787
# ...          ...       ...       ...       ...       ...       ...       ...
# 247056  0.012715  0.286215 -0.193237  0.259055 -0.175520  0.259013  0.124567
# 247057  0.212731  0.135581  0.079503 -0.025656  0.072885  0.118328  0.260708
# 247058 -0.169992  0.054092  0.053043 -0.038903 -0.209773  0.197966  0.430321
# 247059  0.110455  0.361118  0.070931 -0.050831  0.119876  0.214450 -0.122811
# 247060  0.114889 -0.310480 -0.030609 -0.176067  0.220229  0.579760  0.001534
#
#               7         8         9   ...        90        91        92  \
# 0      -0.098358  0.049651 -0.034888  ... -0.092017  0.050891  0.239327
# 1      -0.205908 -0.074108 -0.073762  ... -0.098827  0.053384  0.253159
# 2      -0.016728 -0.342130 -0.328275  ...  0.025500  0.251695  0.200127
# 3      -0.185169  0.080159 -0.133081  ... -0.155108  0.207881  0.054062
# 4      -0.154965  0.019299 -0.093536  ...  0.004821  0.096963 -0.020856
# ...          ...       ...       ...  ...       ...       ...       ...
# 247056 -0.454435  0.060769 -0.079935  ... -0.072250  0.261558  0.579485
# 247057 -0.080643  0.076851  0.041034  ... -0.156632  0.105361  0.026708
# 247058 -0.123014  0.182677 -0.025336  ...  0.036232  0.195696  0.111377
# 247059 -0.223898  0.089509 -0.222808  ...  0.043082  0.552421  0.487870
# 247060 -0.375443 -0.124311 -0.267636  ...  0.207105  0.256516  0.366974
#
#               93        94        95        96        97        98        99
# 0      -0.400130 -0.044502 -0.609984 -0.123225 -0.118359 -0.098331  0.388853
# 1       0.074217  0.025746 -0.202337 -0.085835  0.039945  0.114929  0.032494
# 2      -0.170105 -0.555197 -0.660350  0.013435  0.210020 -0.193558 -0.017185
# 3      -0.164022  0.103973 -0.031730 -0.151994  0.021097  0.048025  0.083719
# 4      -0.116877 -0.030589 -0.004493 -0.019890 -0.082874 -0.166574  0.228325
# ...          ...       ...       ...       ...       ...       ...       ...
# 247056 -0.309292  0.173675 -0.491285 -0.395736 -0.197971  0.289995  0.171095
# 247057 -0.099650 -0.105490 -0.145882 -0.066391 -0.072009  0.037982 -0.032683
# 247058 -0.016318 -0.054676 -0.187137 -0.116381 -0.025897 -0.117413 -0.224302
# 247059 -0.170385 -0.034806 -0.062689 -0.028584 -0.177308  0.224070 -0.187569
# 247060 -0.393539 -0.280398 -0.263858  0.310211  0.015167 -0.088878 -0.080054
#
# [247061 rows x 100 columns]

# %%
r=pd.DataFrame(review_list)
r.to_csv('r.csv')

# %%
r_1=pd.DataFrame(review_list_1)
r_1.to_csv('r_1.csv')

# %%
from sklearn.manifold import TSNE

# Initialize t-SNE
tsne = TSNE(n_components = 2, init = 'random', random_state = 10, perplexity = 100)

# %%
tsne_df = tsne.fit_transform(X_df)

# %%
tsne_df=pd.DataFrame(tsne_df)
final_removed=pd.concat([detokenized_removed,tsne_df],axis=1)

# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

# %%
tagged_data = [TaggedDocument(words=_d, tags=[df['Helpfulness_Label'][i]]) for i, _d in enumerate(cleaned_review)]

# %%
tagged_data
# Out:
# [TaggedDocument(words=['love', 'brushes', 'soft', 'foundation', 'brush', 'washed', 'soon', 'harsh', 'small', 'still', 'always', 'wash', 'brush', 'shed', 'little', 'price', 'good', 'would', 'makeup', 'powder', 'foundation', 'eyeshadow', 'eyeliner', 'cosmetic', 'brushes'], tags=[0]),
#  TaggedDocument(words=['suffer', 'acne', 'however', 'suffer', 'compulsive', 'skin', 'picking', 'condition', 'makes', 'pick', 'little', 'bump', 'skin', 'sometimes', 'without', 'even', 'noticing', 'condition', 'much', 'improved', 'years', 'still', 'occasional', 'picking', 'session', 'tired', 'stressed', 'absorbed', 'work.', 'product', 'helpful', 'journalist', 'writer', 'thus', 'spend', 'long', 'hours', 'writing', 'conducive', 'picking', 'little', 'bump', 'picking', 'dream', 'dots', 'works', 'like', 'charm', 'completely', 'stops', 'picking', 'allowing', 'skin', 'heal', 'also', 'work', 'well', 'overnight', 'healing', 'treatment', 'little', 'scabs', 'small', 'infected', 'areas', 'patches', 'stay', 'well', 'creates', 'moist', 'condition', 'good', 'healing.', 'would', 'highly', 'recommend', 'product', 'especially', 'skin', 'pickers.'], tags=[1]),
#  TaggedDocument(words=['great', 'socks'], tags=[0]),
#  TaggedDocument(words=['absolutely', 'vinyl', 'assumed', 'heat', 'vinyl', 'could', 'scan', 'machine', 'however', 'clue', 'supposed', 'ruined', 'birthday', 'gift', 'tote', 'trying', 'apply', 'iron', 'many', 'using', 'cutting', 'machines', 'idea', 'vinyl', 'supposed', 'even', 'search', 'internet', 'clearing', 'vinyl', 'supposed', 'often', 'happy', 'amazon', 'sending', 'bunch', 'pieces', 'vinyl', 'name', 'beginner', 'figuring', 'happy', 'camper'], tags=[0]),
#  TaggedDocument(words=['pliers', 'great', 'find', 'fishermen', 'easily', 'open', 'split', 'rings', 'nylon', 'braided', 'line', 'attached', 'cord', 'clips', 'easily', 'ring', 'tackle', 'would', 'given', 'another', 'star', 'jaws', 'perfectly', 'align', 'matter', 'seller', 'insisted', 'sending', 'another', 'perfect', 'pair', 'spite', 're-aligning', 'first', 'pair', 'riverbend', 'insisted', 'perfection'], tags=[0]),
#  TaggedDocument(words=['nice', 'quality'], tags=[0]),
#  TaggedDocument(words=['inherited', 'mother', 'eyelashes', 'hardly', 'mother', 'used', 'lash', 'time', 'years', 'wear', 'mascara', 'want', 'lose', 'even', 'lashes', 'washing', 'mascara', 'lashes', 'always', 'came', 'product', 'amazed', 'went', 'watched', 'several', 'tube', 'videos', 'mascara', 'found', 'several', 'choose', 'amazon', 'chose', 'ultra', 'beauty', 'essentials', 'love', 'finally', 'long', 'thick', 'beautiful', 'lashes', 'buying', 'daughter', 'already', 'long', 'lashes', 'tried', 'mine', 'gorgeous', 'several', 'people', 'makeup', 'last', 'nite', 'definitely', 'long', 'time', 'customer', 'love', 'finally', 'beautiful', 'long', 'thick', 'lashes'], tags=[0]),
#  TaggedDocument(words=['assembled', 'together', 'mallets', 'would', 'carrying', 'provided', 'store', 'gear', 'again.', 'played', 'game', 'croquet', 'little', 'head', 'mallet', 'came', 'loose', 'upon', 'found', 'wood', 'threads', 'head', 'mallet', 'stripped', 'would', 'longer', 'hold', 'stick', 'tightly', 'thought', 'gluing', 'decided', 'would', 'likely', 'last', 'returned', 'refund'], tags=[1]),
#  TaggedDocument(words=['stick', 'well', 'problems', 'placement', 'fact', 'anything', 'took', 'effort', 'remove', 'sensitivity', 'minutes', 'felt', 'like', 'went', 'roots', 'area', 'mouth', 'time', 'first', 'never', 'problem', 'plan', 'need'], tags=[0]),
#  TaggedDocument(words=['brush', 'razor'], tags=[1]),
#  TaggedDocument(words=['delivered', 'time', 'workedas', 'expected', 'clear', 'really', 'requies', 'help', 'second', 'person', 'apply/'], tags=[0]),
#  TaggedDocument(words=['helps', 'exercises', 'neck', 'upper', 'back', 'seems', 'good', 'quality'], tags=[0]),
#  TaggedDocument(words=['first', 'pillowcase', 'keep', 'clean', 'woke', 'also.', 'tried', 'keeping', 'pillow', 'like', 'putting', 'pillowcase', 'starts', 'cold', 'morning', 'head', 'tried', 'moving', 'head', 'cold', 'started'], tags=[0]),
#  TaggedDocument(words=['soap', 'dispenser', 'excellent', 'dispenses', 'perfect', 'amount', 'soap', 'much', 'less', 'used', 'saving', 'soap', 'never', 'dispenser', 'greasy', 'dirty', 'never', 'touch', 'hands', 'wonderful', 'invention'], tags=[0]),
#  TaggedDocument(words=['small', 'ankles'], tags=[1]),
#  TaggedDocument(words=['works', 'great', 'toilets'], tags=[1]),
#  TaggedDocument(words=['false', 'advertising', 'flat', 'sitting', 'flattens', 'butt', 'thighs', 'goes', '~1/2', 'inch', 'weigh', 'lbs.', '12/21/2015', 'revising', 'stars', 'great', 'customer', 'service', 'seller', 'contacted', 'sent', 'another', 'cushion', 'style', 'couple', 'weeks', 'testing', 'office', 'chair', 'compresses', 'greatly', 'thick'], tags=[1]),
#  TaggedDocument(words=['nice', 'quality', 'great'], tags=[0]),
#  TaggedDocument(words=['arrived', 'quickly', 'nice', 'item', 'works', 'well'], tags=[0]),
#  TaggedDocument(words=['stun', 'feels', 'looks', 'like', 'quality', 'product.i', 'carry', 'walks', 'every', 'holster', 'cheaply', 'made', 'works', 'attacked', 'several', 'times', 'stray', 'dogs', 'seriously', 'injured', 'device', 'stop', 'without', 'injuring', 'harms', 'flashlight', 'feature', 'nice', 'bonus', 'beat', 'price'], tags=[0]),
#  TaggedDocument(words=['difference', 'skin', 'almost', 'immediately', 'skin', 'firmer', 'definitely', 'brighter', 'seen', 'difference', 'dark', 'spots', 'using', 'weeks', 'definitely', 'make', 'serum', 'regular', 'part', 'beauty', 'regime'], tags=[0]),
#  TaggedDocument(words=['natural', 'deoderant', 'actually', 'works'], tags=[0]),
#  TaggedDocument(words=['purchase', 'item', 'used', 'getting', 'nails', 'done', 'need', 'drop', 'great', 'latter', 'soon', 'tell', 'good', 'think', 'says'], tags=[0]),
#  TaggedDocument(words=['works', 'great', 'easy', 'install'], tags=[0]),
#  TaggedDocument(words=['fake', 'product', 'good'], tags=[0]),
#  TaggedDocument(words=['great', 'surprise', 'midshipman', 'love', 'wrapped', 'portions'], tags=[1]),
#  TaggedDocument(words=['running', 'dark', 'morning', 'great', 'bright', 'reflective', 'make', 'feel', 'much', 'visible', 'therefore', 'much', 'safer', 'running', 'belt', 'adjusts', 'small', 'waist', 'large', 'waist', 'work', 'people', 'varying', 'sizes', 'main', 'material', 'nice', 'soft', 'stretchy', 'clasp', 'belt', 'seems', 'solid', 'easy', 'like', 'cuffs', 'large', 'initially', 'tried', 'putting', 'ankles', 'wear', 'sweat', 'bands', 'wrists', 'seemed', 'like', 'would', 'stuff', 'around', 'wrists', 'around', 'ankles', 'fine', 'velcro', 'material', 'used', 'attach', 'cuff', 'stiff', 'afraid', 'without', 'fabric', 'barrier', 'cuff', 'might', 'eventually', 'chafe', 'wearing', 'running', 'tights', 'would', 'probably', 'given', 'moved', 'wrists', 'worked', 'fine', 'caveat', 'product', 'everyone', 'would', 'need', 'cuffs', 'around', 'ankles', 'issue', 'cuffs', 'measure', 'inches', 'long', 'inches', 'wide', 'plastic', 'type', 'velcro', 'inches', 'softer', 'side', 'velcro', 'inches', 'inches', 'cuff', 'allow', 'stretch', 'around', 'work', 'boots', 'anything', 'would', 'probably', 'would', 'work', 'you.', 'caveats', 'mentioned', 'would', 'highly', 'recommend', 'product', 'anyone', 'regularly', 'dark', 'around', 'traffic', 'stay', 'safe'], tags=[1]),
#  TaggedDocument(words=['family', 'loved'], tags=[1]),
#  TaggedDocument(words=['absolutely', 'beautiful', 'well', 'made'], tags=[0]),
#  TaggedDocument(words=['fantastic', 'towels', 'soft', 'easy', 'care', 'replacing', 'towels', 'wroth'], tags=[0]),
#  TaggedDocument(words=['item', 'arrived', 'shape', 'looks', 'awesome', 'wall', 'came', 'simple', 'follow', 'decal', 'went', 'wall', 'easily'], tags=[0]),
#  TaggedDocument(words=['great', 'gifts', 'every', 'pictures', 'nice', 'always', 'frame', 'around'], tags=[0]),
#  TaggedDocument(words=['absolutely', 'beautiful', 'make', 'feet', 'look', 'dainty', 'stylish', 'without', 'sandals', 'footless', 'sandals'], tags=[0]),
#  TaggedDocument(words=['doesnt', 'well'], tags=[0]),
#  TaggedDocument(words=['great', 'cherry', 'soda', 'package', 'packed', 'perfect', 'worth'], tags=[1]),
#  TaggedDocument(words=['work', 'great', 'never', 'issue'], tags=[1]),
#  TaggedDocument(words=['works', 'advertised'], tags=[0]),
#  TaggedDocument(words=['absolutely', 'love', 'product', 'works', 'miracles..'], tags=[1]),
#  TaggedDocument(words=['ordered', 'couple', 'weeks', 'hanging', 'front', 'room', 'since', 'adds', 'nice', 'touch', 'little', 'darker', 'pictured', 'edges', 'little', 'sharp', 'looks', 'great', 'seller', 'emailed', 'shortly', 'delivery', 'make', 'sure', 'liked', 'overall', 'pleased', 'piece'], tags=[1]),
#  TaggedDocument(words=['mostly', 'vanilla', 'flavor', 'homemade', 'yogurt', 'satisfied', 'quality', 'beans', 'flavor', 'impart', 'reorder'], tags=[1]),
#  TaggedDocument(words=['works', 'like', 'charm', 'especially', 'love', 'gives', 'many', 'warning', 'beeps', 'allows', 'hound', 'stray', 'barks', 'playing', 'trains', 'bark'], tags=[1]),
#  TaggedDocument(words=['bought', 'husband', 'absolutely', 'love'], tags=[0]),
#  TaggedDocument(words=['best', 'vitamin', 'serum', 'face', 'wonderful', 'product', 'absorbs', 'easily', 'heavy', 'product', 'simply', 'lays', 'skin', 'greasy', 'important', 'well', 'frangrance', 'wonderful', 'feedback', 'seller', 'product', 'order', 'pleased', 'stars'], tags=[0]),
#  TaggedDocument(words=['work'], tags=[0]),
#  TaggedDocument(words=['magpul', 'quality', 'expected', 'works', 'great', 'complaints'], tags=[0]),
#  TaggedDocument(words=['enjoys', 'taste', 'wild', 'fussy', 'happy', 'find', 'product'], tags=[0]),
#  TaggedDocument(words=['great', 'knive', 'really', 'happy'], tags=[0]),
#  TaggedDocument(words=['pillow', 'smelled', 'like', 'mold', 'received', 'still', 'smells', 'like', 'mold', 'open', 'quite', 'time', 'attempted', 'bath', 'suction', 'cups', 'fell', 'easily', 'back', 'came', 'pillow', 'back', 'bathtub', 'really', 'hard', 'bath', 'pillow', 'glad', 'order', 'gift', 'friend', 'relative', 'tried', 'really', 'waste', 'money'], tags=[0]),
#  TaggedDocument(words=['made', 'excellent', 'brownies'], tags=[0]),
#  TaggedDocument(words=['yoga'], tags=[0]),
#  TaggedDocument(words=['blizzard', 'conditions', 'mind', 'vest', 'exceeds', 'l/xl', 'size', 'fits', 'bulky', 'winter', 'coats', 'easy', 'adjust', 'easy', 'remove', 'perfect', 'highly', 'visible', 'vest', 'looking', 'belts', 'wide', 'bright', 'making', 'easily', 'seen', 'vehicles', 'snow', 'plows', 'visibility', 'conditions', 'highly', 'recommend', 'product', 'anyone', 'must', 'matter', 'conditions', 'confidence', 'safety', 'highest', 'level', 'possible', 'passing', 'drivers', 'called', 'great', 'vest', 'would', 'seen', 'without'], tags=[0]),
#  TaggedDocument(words=['bought', 'sure', 'least', 'would', 'work', 'neither', 'works', 'waste', 'time', 'money', 'different', 'fitbit', 'pedometers', 'great', 'guess', 'quality', 'costs'], tags=[0]),
#  TaggedDocument(words=['good', 'quality', 'still', 'pricey', 'nice', 'lots', 'room', 'color', 'great', 'pricey', 'nike'], tags=[0]),
#  TaggedDocument(words=['edit', 'given', 'refund', 'want', 'thank', 'wonderful', 'customer', 'service', 'wish', 'contacted', 'wrote', 'review', 'online', 'shopping', 'thank', 'changed', 'stars', 'hopefully', 'change', 'shows', 'original', 'wrong', 'tool', 'works', 'great', 'tool', 'similar', 'design', 'effective', 'whether', 'steam', 'face', 'first', 'however', 'product', 'overpriced', 'mail', 'today', 'ordered', 'extractor', 'previously', 'ordered', 'drugstore', 'nearby', 'lost', 'scratches', 'metal', 'flat', 'headed', 'side', 'kind', 'similar', 'cheap', 'jewelry', 'silver', 'paint', 'chips', 'kind', 'upsetting', 'since', 'brand', 'guess', 'hopefully', 'last', 'plus', 'side', 'besides', 'fact', 'works', 'packaging', 'design', 'super', 'cute', 'durable'], tags=[0]),
#  TaggedDocument(words=['candles', 'pretty', 'similar', 'real', 'candles', 'liked'], tags=[0]),
#  TaggedDocument(words=['matcha', 'great', 'exactly', 'expected', 'works', 'well', 'black', 'smoothies', 'definitely'], tags=[0]),
#  TaggedDocument(words=['product', 'easy', 'comes', 'data', 'plan', 'online', 'portal', 'lots', 'options', 'track', 'vehicle', 'customer', 'service', 'amazing', 'looked', 'options', 'best', 'user', 'interface', 'features', 'price', 'extremely', 'reasonable'], tags=[0]),
#  TaggedDocument(words=['using', 'hair', 'week', 'hair', 'less', 'frizzy', 'looks', 'tame', 'drops', 'needed'], tags=[0]),
#  TaggedDocument(words=['clasp', 'fallen', 'apart', 'twice', 'since', 'purchased', 'less', 'months', 'first', 'time', 'able', 'find', 'pieces', 'back', 'together', 'second', 'time', 'much'], tags=[0]),
#  TaggedDocument(words=['like', 'original'], tags=[1]),
#  TaggedDocument(words=['cats', 'love'], tags=[0]),
#  TaggedDocument(words=['certainly', 'make', 'lifting', 'heavy', 'king', 'mattress', 'easier', 'wish', 'lifted'], tags=[1]),
#  TaggedDocument(words=['rough', 'heals', 'pumice', 'stone', 'would', 'remove', 'used', 'electric', 'shaver', 'found', 'heals', 'much', 'better', 'next', 'applied', 'lotion', 'bed.', 'easy', 'would', 'recommend'], tags=[1]),
#  TaggedDocument(words=['ripped', 'apart', 'first', 'time', 'tried', 'them.will', 'using', 'different', 'product'], tags=[0]),
#  TaggedDocument(words=['friends', 'enjoy', 'gift', 'still', 'able', 'whole', 'ball', 'destroyed', 'mins', 'rope', 'took', 'longer', 'also', 'destroyed', 'within', 'least', 'time', 'play', 'gone'], tags=[0]),
#  TaggedDocument(words=['love', 'product', 'works', 'recommend', 'wants', 'radiant', 'skin'], tags=[0]),
#  TaggedDocument(words=['time', 'waiting', 'someone', 'make', 'pouch', 'protein', 'kids', 'huge', 'eaters', 'pouch', 'applesauce', 'carry', 'enough', 'smashpack', 'better', 'kids', 'love', 'dense', 'thick', 'takes', 'longer', 'versus', 'applesauce', 'kids', 'actually', 'full', 'portable', 'fast', 'protein', 'girl', 'could', 'particular', 'ingredients', 'convenience', 'foods', 'family', 'smashpack', 'clean', 'thank', 'goodness'], tags=[0]),
#  TaggedDocument(words=['looks', 'real', 'good'], tags=[0]),
#  TaggedDocument(words=['easy', 'install', 'keeps', 'living', 'room', 'comfortable'], tags=[1]),
#  TaggedDocument(words=['received', 'product', 'quickly', 'lotion', 'pretty', 'bottle', 'nice', 'scent', 'thick', 'hard', 'absorb', 'skin'], tags=[0]),
#  TaggedDocument(words=['skin', 'feels', 'balanced', 'much', 'clearer', 'using', 'product', 'seller', 'contacts', 'make', 'sure', 'product', 'shipping', 'fast', 'skeptical', 'toners', 'sure', 'lifetime', 'customer'], tags=[0]),
#  TaggedDocument(words=['pretty', 'hesitant', 'buying', 'case', 'glad', 'love', 'thing', 'unpleasant', 'smell', 'case', 'hopefully', 'goes', 'away'], tags=[1]),
#  TaggedDocument(words=['dispensers', 'nice', 'never', 'says', 'holds', 'poop', 'really', 'sure', 'take', 'word'], tags=[1]),
#  TaggedDocument(words=['longer', 'handle', 'tangle', 'teezer', 'gives', 'much', 'better', 'feeling', 'dealing', 'long', 'thick', 'hairs'], tags=[0]),
#  TaggedDocument(words=['purchased', 'display', 'learning', 'signs', 'charts', 'fridge', 'work', 'perfectly', 'need', 'write', 'erase', 'markers', 'easily', 'wipe', 'flexible', 'solid', 'plastic', 'highly', 'recommend', 'anybody', 'wants', 'display', 'anything', 'magnetic', 'surface'], tags=[1]),
#  TaggedDocument(words=['roomba', 'runs', 'everyday', 'four', 'dogs', 'time', 'another', 'brushes'], tags=[0]),
#  TaggedDocument(words=['quit', 'working', 'right', 'changed', 'batteries', 'still', 'work', 'happy', 'item'], tags=[1]),
#  TaggedDocument(words=['worked', 'couple', 'days'], tags=[0]),
#  TaggedDocument(words=['waste', 'money', 'item', 'terrible', 'de-ployed', 'would', 'un-de-ploy', 'back', 'position', 'return', 'long'], tags=[0]),
#  TaggedDocument(words=['wonderful', 'better', 'stronger', 'feathers', 'come', 'original', 'wand', 'company'], tags=[1]),
#  TaggedDocument(words=['purchased', '6-month', 'kitten', 'plays', 'every', 'endorsement', 'gave', 'christmas', 'presents', 'elderly', 'middle-aged', 'tabby', 'told', 'gift', 'recipients', 'toys', 'peaches', 'believe', 'ever', 'seen', 'successful', 'would', 'highly', 'recommend'], tags=[1]),
#  TaggedDocument(words=['first', 'great', 'looks', 'nice', 'loves', 'however', 'eventually', 'need', 'wash', 'shown', 'pictures', 'bottom', 'removable', 'cover', 'made', 'thinner', 'material', 'material', 'completely', 'shredded', 'wash', 'unusable', 'costs', 'much', 'think', 'quality', 'would', 'able', 'stand', 'washing', 'washed', 'label'], tags=[1]),
#  TaggedDocument(words=['like', 'sweet', 'chocolate'], tags=[0]),
#  TaggedDocument(words=['loved', 'item', 'fits', 'ruger', 'like', 'glove', 'wiggle', 'play', 'little', 'smaller', 'piece', 'goes', 'bottom', 'bigger', 'piece', 'goes', 'make', 'little', 'heavier', 'cant', 'beat', 'price', 'bravo'], tags=[1]),
#  TaggedDocument(words=['described'], tags=[0]),
#  TaggedDocument(words=['pungent', 'smell', 'deters', 'using', 'otherwise', 'design', 'features', 'fine', 'zipper', 'spans', 'wide', 'allows', 'place', 'paddle', 'without', 'touching', 'padding', 'therefore', 'minimizing', 'handling', 'paddle', 'maintaining', 'tackiness', 'little', 'pocket', 'ping', 'pong', 'ball', 'caution', 'using', 'type', 'book', 'something', 'heavy', 'paddle', 'case', 'months', 'smell', 'still', 'present', 'stars', 'smell'], tags=[1]),
#  TaggedDocument(words=['purchasing', 'product', 'routine', 'research', 'tried', 'find', 'much', 'information', 'light', 'worth', 'compared', 'o-light', 'whole', 'price', 'difference', 'quality', 'power', 'completely', 'different.', 'hours', 'research', 'went', 'amazon', 'ordered', 'light.', 'days', 'past', 'arrived', 'today', '8-3-2015', 'received', 'hours', 'really', 'enjoying', 'light.', 'package', 'quality', 'simple', 'stuffed', 'packing', 'peanuts.', 'structure', 'light', 'seems', 'strong', 'flimsy', 'parts', 'included', 'pocket', 'clip', 'strongest', 'come', 'across', 'pocket', 'light', 'retention', 'dead', 'product', 'carried', 'flashlight', 'roughly', 'lumens', 'become', 'back', 'sitting', 'glovebox', 'car.', 'compared', 'light', 'pistol', 'light', 'streamlight', 'tlr1-hl', 'lumens', 'thrunite', 'hold', 'needed.', 'throw', 'decent', 'flood', 'strong', 'strong', 'spot.', 'surefire', 'cr123a', 'batteries', 'lights', 'take', 'them.', 'would', 'recommend', 'light', 'anyone', 'looking', 'power', 'compact', 'body.', 'wish', 'able', 'upload', 'pictures', 'show', 'beam', 'thrunite', 'compared', 'stream', 'light', 'upload'], tags=[0]),
#  TaggedDocument(words=['kayaking', 'mostly', 'lots', 'room', 'keeps', 'stuff', 'easy', 'carry', 'color', 'stands', 'blue', 'great', 'hand', 'activity', 'occasion', 'involves', 'inclement', 'weather', 'elements', 'highly', 'recommend'], tags=[0]),
#  TaggedDocument(words=['working', 'took', 'advice', 'others', 'reviews', 'intake'], tags=[0]),
#  TaggedDocument(words=['loved', 'sheets', 'went', 'sleep', 'smiling', 'soft'], tags=[0]),
#  TaggedDocument(words=['love', 'bands', 'confortable', 'wear', 'hard', 'little', 'clamp', 'properly', 'thrilled', 'colors', 'since', 'received', 'bright', 'colors', 'lots', 'boring', 'colors', 'pink', 'really', 'wanted', 'work', 'great', 'fitbit'], tags=[0]),
#  TaggedDocument(words=['green', 'chocolates', 'amazing'], tags=[0]),
#  TaggedDocument(words=['wonderful', 'product'], tags=[0]),
#  TaggedDocument(words=['smoothies'], tags=[0]),
#  TaggedDocument(words=['truly', 'like', 'product'], tags=[0]),
#  TaggedDocument(words=['kids', 'loved'], tags=[0]),
#  TaggedDocument(words=['like', 'container', 'pump', 'worked', 'soften', 'lines', 'blown', 'away', 'results'], tags=[0]),
#  TaggedDocument(words=['looking', 'forward', 'using', 'opportunity', 'purchased', 'work', 'track', 'miles', 'time'], tags=[0]),
#  TaggedDocument(words=['found', 'refreshing', 'north', 'carolina', 'working', 'yard'], tags=[1]),
#  TaggedDocument(words=['received', 'collar', 'saturday', 'afternoon', 'incestant', 'barker', 'bark', 'people', 'walking', 'front', 'house', 'people', 'sees', 'hedges', 'peoples', 'back', 'yards', 'side', 'block', 'squirrels', 'well', 'anything.', 'read', 'directions', 'much', 'easy', 'within', 'minutes', 'collar', 'started', 'barking', 'tone', 'came', 'collar', 'enough', 'turn', 'head', 'wonder', 'came', 'stopped', 'barking', 'also', 'invisable', 'fence', 'tone', 'differeent', 'dirrentiate', 'tone', 'fence', 'think', 'important.', 'outside', 'back', 'yard', 'neighbor', 'came', 'home', 'naturally', 'barked', 'heard', 'tone', 'stopped', 'barking', 'minutes', 'later', 'people', 'walked', 'front', 'house', 'front', 'barking', 'could', 'hear', 'tone', 'sounding', 'rounded', 'corner', 'barked', 'probably', 'series', 'barks', 'stopped', 'normally', 'would', 'bark', 'bark', 'could', 'longer', 'know', 'shocker', 'kicked', 'stopped', 'tone', 'sounding', 'either', 'worked', 'desired', 'brings', 'part', 'collar', 'like', 'best', 'uses', 'tone', 'sound', 'warning', 'uses', 'static', 'shock.', 'going', 'camping', 'weekend', 'continue', 'review', 'back', 'huge', 'test', 'effective', 'collar', 'really', 'people', 'walking', 'campsite', 'weekend'], tags=[1]),
#  TaggedDocument(words=['awesome', 'puppy', 'really', 'total', 'rockstar', 'knew', 'whole', 'originally', 'using', 'fancy', 'bags', 'total', 'foolishness', 'amazon', 'basics', 'logo', 'wonderful', 'stack', 'endless', 'poops', 'bags', 'know', 'done', 'something', 'right', 'world', 'bags', 'thin', 'totally', 'unbreakable', 'know', 'within', 'reason', 'come', 'apart', 'easily', 'lovely', 'little', 'assuming', 'thing', 'give', 'dispenser', 'think.', 'gripe', 'really', 'annoying', 'open', 'bags', 'wish', 'clever', 'amazon', 'perforate', 'sides', 'bags', 'different', 'places', 'maybe', 'even', 'every', 'time', 'might', 'make', 'easier', 'open', 'rush', 'anyway', 'good', 'stuff'], tags=[1]),
#  TaggedDocument(words=['better', 'expected', 'reviews', 'thought', 'would', 'soft', 'although', 'soft', 'feel', 'quite', 'sturdy', 'perfect', 'cushions', 'also', 'used', 'loveseat', 'pleased'], tags=[0]),
#  TaggedDocument(words=['dope', 'good', 'price', 'highly', 'recommended', 'floyd', 'money', 'mayweather', 'fans'], tags=[0]),
#  TaggedDocument(words=['oder', 'unpleasant'], tags=[0]),
#  TaggedDocument(words=['bought', 'knowing', 'refurbished', 'definitely', 'tell', 'used', 'quite', 'satisfied', 'long', 'performs', 'well', 'seem', 'much', 'suction', 'dyson', 'hoping'], tags=[0]),
#  TaggedDocument(words=['first', 'review', 'regards', 'nose', 'clip', 'swim', 'ipod', 'earbuds', 'need', 'earplugs', 'also', 'purchased', 'received', 'email', 'stating', 'given', 'discount', 'exchange', 'review', 'remember', 'seeing', 'purchased', 'effect', 'said', 'purchase', 'review', 'purchased', 'different', 'nose', 'clips', 'address', 'review.', 'first', 'always', 'cressi', 'product', 'user', 'know', 'stuff', 'seems', 'face', 'better', 'female', 'seems', 'like', 'products', 'designed', 'children', 'cressi', 'nose', 'plug', 'year', 'plastic', 'really', 'hard', 'also', 'seemed', 'like', 'dissolving', 'like', 'piece', 'mouth', 'long', 'near', 'kind', 'soured', 'particular', 'product', 'thought', 'others.', 'first', 'product', 'tried', 'swim', 'elite', 'plug', 'surprised', 'first', 'looking', 'picture', 'expecting', 'plastic', 'straps', 'across', 'nose', 'sides', 'rounded', 'raised', 'mistakingly', 'thought', 'separate', 'pieces', 'deal', 'except', 'nose', 'clip', 'almost', 'identical', 'piece', 'swim', 'swimming', 'clear', 'como', 'como', 'half', 'price', 'twice', 'product', 'enough', 'slight', 'differences', 'copyright', 'purposes', 'sure', 'function', 'exactly', 'first', 'looked', 'little', 'concerned', 'nose', 'pads', 'look', 'cheap', 'poorly', 'attached', 'sure', 'long', 'last', 'sure', 'life', 'expectancy', 'nose', 'plugs', 'anyway', 'washed', 'face', 'read', 'reviews', 'people', 'problems', 'faces', 'test', 'manipulate', 'nose', 'much', 'give', 'plastic', 'speak', 'aware', 'swam', 'across', 'pool', 'felt', 'like', 'going', 'fall', 'slid', 'nose', 'swam', 'regular', 'program', 'stayed', 'feeling', 'like', 'going', 'come', 'whole', 'time', 'also', 'noted', 'could', 'blow', 'nose', 'assuming', 'could', 'breathe', 'breathed', 'nose', 'tried', 'next', 'couple', 'days', 'results', 'never', 'came', 'still', 'felt', 'overall', 'acceptable', 'back', 'product.', 'next', 'tried', 'piece', 'swim', 'combo', 'como', 'essentially', 'identical', 'swim', 'elite', 'product', 'issues', 'review', 'inexpensive', 'nose', 'plugs', 'earplugs', 'brainer', 'back', 'everyday', 'plug', 'tried', 'sodial', 'beige', 'string', 'clip', 'awful', 'super', 'hard', 'plastic', 'strap', 'obnoxious', 'need', 'anything', 'else', 'around', 'head', 'swim', 'goggles', 'almost', 'painful', 'almost', 'would', 'stay', 'small', 'part', 'goes', 'nose', 'short', 'nose', 'beak', 'like', 'nose', 'thin', 'pointy', 'even', 'make', 'middle', 'nose', 'might', 'work', 'someone', 'really', 'short', 'flat', 'nose', 'child', 'sure', 'plastic', 'also', 'made', 'cressi', 'know', 'happens', 'awhile', 'definite', 'even', '2.22', 'would', 'ever', 'went', 'trash.', 'final', 'product', 'harmony', 'smiley', 'nose', 'plug', 'best', 'bunch', 'really', 'comparison', 'pads', 'right', 'amount', 'cushion', 'firmness', 'stay', 'place', 'completely', 'plug', 'nose', 'part', 'goes', 'bridge', 'nose', 'metal', 'seems', 'like', 'might', 'hold', 'better', 'plastic', 'cressi', 'metal', 'bridged', 'still', 'intact', 'manipulate', 'nose', 'little', 'results', 'mind', 'drawback', 'swimmer', 'cord', 'attached', 'little', 'pain', 'butt', 'done', 'offer', 'option', 'without', 'cord', 'could', 'useful', 'kayaker', 'steal', 'would', 'definitely', 'purchase', 'maybe', 'even', 'second', 'backup', 'nose', 'plugs', 'left', 'dents', 'nose', 'went', 'away', 'hour', 'swim', 'right', 'need', 'somewhere', 'important', 'might', 'find', 'trying', 'explain', 'wanted', 'include', 'experience', 'products', 'review', 'often', 'times', 'read', 'others', 'reviews', 'saying', 'liked', 'another', 'product', 'better', 'never', 'mention', 'product', 'liked', 'swim', 'everyday', 'comfort', 'equally', 'important', 'hopefully', 'information', 'helpful', 'someone', 'else'], tags=[1]),
#  TaggedDocument(words=['beautifull'], tags=[0]),
#  TaggedDocument(words=['good', 'stay'], tags=[0]),
#  TaggedDocument(words=['heard', 'good', 'things', 'soap', 'cleared', 'daughters', 'acne', 'expect', 'immediate', 'results', 'woman', 'happy', 'aging', 'done', 'face', 'using', 'soap', 'face', 'actually', 'feel', 'cleansing', 'toning', 'skin', 'skin', 'soft', 'years', 'wait', 'results', 'using', 'weeks'], tags=[1]),
#  TaggedDocument(words=['purchased', 'virgin', 'argan', 'absolutely', 'love', 'arrived', 'time', 'actually', 'business', 'early', 'awesome', 'used', 'time', 'difference', 'skin', 'purchased', 'derma', 'roller', 'well', 'used', 'used', 'derma', 'roller', 'better', 'results', 'continue', 'product', 'purchase', 'must', 'skeptical', 'unsure', 'product', 'would', 'actually', 'work', 'hoping', 'gain', 'glad', 'decided', 'give', 'try..you'], tags=[0]),
#  TaggedDocument(words=['bigger', 'bath', 'beyond', 'perfect', 'daughters', 'college'], tags=[0]),
#  TaggedDocument(words=['jewelry', 'fell', 'could', 'case', 'pretty', 'though'], tags=[0]),
#  TaggedDocument(words=['bought', 'said', 'least', 'dollars', 'cheaper', 'store', 'goes', 'true', 'product', 'exactly', 'sold', 'stores'], tags=[0]),
#  TaggedDocument(words=['puppy', 'loved', 'seems', 'strong', 'well', 'made'], tags=[1]),
#  TaggedDocument(words=['absolutely', 'love', 'product..', 'amazing', 'wood', 'floors'], tags=[0]),
#  TaggedDocument(words=['great', 'quality', 'product', 'love', 'design', 'like'], tags=[0]),
#  TaggedDocument(words=['item', 'returned', 'misread', 'description', 'thought', 'pillows', 'included', 'well'], tags=[0]),
#  TaggedDocument(words=['arrived', 'weeks', 'estimated', 'besides', 'poster', 'came', 'great', 'condition', 'framed', 'looks', 'fantastic'], tags=[1]),
#  TaggedDocument(words=['good', 'finish'], tags=[0]),
#  TaggedDocument(words=['love', 'colors'], tags=[0]),
#  TaggedDocument(words=['wearing', 'compression', 'foot', 'sleeves', 'past', 'days', 'could', 'pleased', 'went', 'podiatrist', 'diagnosed', 'plantar', 'fasciitis', 'gave', 'cortisone', 'shot', 'knowing', 'problem', 'heel', 'already', 'ordered', 'received', 'sleeves', 'told', 'heel', 'better', 'come', 'back', 'week', 'another', 'shot', 'amazement', 'wearing', 'sleeves', 'pain', 'diminished', 'require', 'additional', 'shot.', 'thank', 'satisfied', 'customer', 'janet', 'seidel'], tags=[1]),
#  TaggedDocument(words=['like', 'light', 'weight', 'nice', 'mild', 'fragrance', 'soften', 'hands', 'well', 'arms', 'especially', 'elbow', 'area', 'thank', 'seller', 'also', 'utilized', 'sunscreen'], tags=[0]),
#  TaggedDocument(words=['expected'], tags=[0]),
#  TaggedDocument(words=['great', 'feel', 'like', 'stole', 'price', 'comfortable', 'hand'], tags=[0]),
#  TaggedDocument(words=['good', 'year', 'bolognese', 'probiotic', 'days', 'well', 'seemed', 'clear', 'bowl', 'usual', 'normal', 'regular', 'complaints', 'fast', 'shipping'], tags=[0]),
#  TaggedDocument(words=['needed', 'powder', 'make', 'green', 'cream', 'maybe', 'condensed', 'flavor', 'usual', 'used', 'quite', 'much', 'recipe', 'called', 'flavor', 'slightly', 'bitter', 'seller', 'exactly', 'supposed', 'product', 'arrived', 'exactly', 'advertised', 'give', 'lighter', 'green', 'flavor', 'looking'], tags=[1]),
#  TaggedDocument(words=['already', 'completed', 'first', 'project', 'hooks', 'love', 'cramping', 'hand', 'nice', 'packaging', 'everything', 'kept', 'neatly', 'organized', 'price', 'great'], tags=[0]),
#  TaggedDocument(words=['hair', 'rescue', 'gold', 'plus', 'hair', 'growth', 'supplement', 'hair', 'vitamins', 'treatment', 'rebirth', 'hair', 'awakening', 'roots', 'different', 'vitamins', 'nutrients', 'implemented', 'product', 'make', 'hair', 'healthy', 'keep', 'healthy', 'product', 'helps', 'remove', 'stress', 'roots', 'relax', 'bring', 'growth', 'fullness', 'vitality'], tags=[0]),
#  TaggedDocument(words=['glad', 'happened', 'upon', 'product', 'tried', 'everything', 'gentle', 'leader', 'easy', 'walk', 'harness', 'prong', 'collar', 'nothing', 'worked', 'evie', 'still', 'pulled', 'much', 'thought', 'right', 'going', 'longer.', 'leash', 'presto', 'pulling.', 'thank', 'thank', 'thank', 'you.', 'sue.', 'picture', 'evie', 'looking', 'happy', 'longer', 'walks'], tags=[0]),
#  TaggedDocument(words=['heavy', 'duty', 'sheets', 'really', 'comfortable', 'sleep'], tags=[0]),
#  TaggedDocument(words=['noticed', 'difference'], tags=[0]),
#  TaggedDocument(words=['product', 'seems', 'working', 'seeing', 'cats', 'vomit', 'much', 'also', 'changed', 'food', 'cats', 'dogs', 'eating', 'though', 'something', 'never', 'happened', 'cats', 'hint', 'supplement', 'would', 'touch', 'pureall', 'seem', 'mind', 'seems', 'like', 'great', 'product'], tags=[0]),
#  TaggedDocument(words=['love', 'safety', 'aspect', 'losing', 'fitbit', 'also', 'cute', 'change', 'colors', 'bands', 'hesitate'], tags=[0]),
#  TaggedDocument(words=['speedy', 'delivery', 'function', 'perfectly'], tags=[0]),
#  TaggedDocument(words=['nice'], tags=[0]),
#  TaggedDocument(words=['great', 'product', 'high', 'quality', 'exactly', 'supposed', 'highly', 'recommend', 'purchase', 'similar', 'expensive', 'products'], tags=[0]),
#  TaggedDocument(words=['look', 'like', 'natural', 'lashes'], tags=[0]),
#  TaggedDocument(words=['snaps', 'difficult', 'keep', 'large', 'size', 'would', 'better', 'assortment', 'colors', 'work', 'though'], tags=[0]),
#  TaggedDocument(words=['friends', 'fans'], tags=[0]),
#  TaggedDocument(words=['price', 'paid', 'thickness', 'good', 'deal'], tags=[0]),
#  TaggedDocument(words=['feel', 'super', 'lucky', 'found', 'adore', 'clarisonic', 'brushes', 'expensive', 'current', 'budget', 'perfectly', 'working', 'great'], tags=[1]),
#  TaggedDocument(words=['looks', 'great', 'wall'], tags=[0]),
#  TaggedDocument(words=['perfect', 'seems', 'decently', 'build', 'money', 'weekend', 'test'], tags=[0]),
#  TaggedDocument(words=['bought', 'wife', 'looks', 'great', 'complaint', 'bangle', 'small', 'wrist', 'like', 'fact', 'open', 'clasp', 'good', 'thing', 'petite', 'anyone', 'bigger', 'wrist', 'would', 'able', 'wear'], tags=[0]),
#  TaggedDocument(words=['currently', 'weeks', 'pregnant', 'using', 'pillow', 'weeks', 'bought', 'using', 'four', 'standard', 'pillows', 'comfortable', 'much', 'better.', 'love', 'support', 'behind', 'back', 'belly', 'knees', 'pillow', 'little', 'firm', 'think', 'needs', 'work', 'well', 'took', 'little', 'neck', 'used', 'broken', 'little', 'sleep', 'problems.', 'sleep', 'queen', 'pillow', 'takes', 'good', 'portion', 'husband', 'says', 'still', 'enough', 'room', 'comfortable'], tags=[0]),
#  TaggedDocument(words=['elegant', 'good', 'recommended'], tags=[0]),
#  TaggedDocument(words=['great', 'sweeper', 'delivered', 'speedily', 'works', 'wonderfully'], tags=[0]),
#  TaggedDocument(words=['really', 'thick', 'also', 'started', 'ripping', 'little', 'area', 'within', 'weeks', 'constant', 'definitely', 'long', 'term', 'product', 'going', 'constantly'], tags=[0]),
#  TaggedDocument(words=['love', 'piece', 'gives', 'rifle', 'amazing', 'touch'], tags=[0]),
#  TaggedDocument(words=['appear', 'great', 'quality', 'comfortable', 'sleep', 'large', 'enough', 'completely', 'cover', 'large', 'pillow', 'mattress'], tags=[0]),
#  TaggedDocument(words=['described', 'favorite', 'tough', 'nails', 'however'], tags=[0]),
#  TaggedDocument(words=['much', 'problems', 'finding', 'size', 'filters'], tags=[0]),
#  TaggedDocument(words=['love', 'came', 'described', 'look', 'wonderful.', 'complaint', 'packaging', 'staple', 'packaging', 'right', 'back', 'frame', 'definitely', 'risks', 'damage', 'shipping', 'thank', 'goodness', 'problem', 'opening', 'tricky', 'package', 'others', 'received', 'possibly', 'damaged', 'also', 'difficult', 'staples', 'frame', 'attach', 'packaging', 'ended', 'lightly', 'hammering', 'method', 'packaging', 'solid', 'product'], tags=[1]),
#  TaggedDocument(words=['works', 'good'], tags=[0]),
#  TaggedDocument(words=['great'], tags=[0]),
#  TaggedDocument(words=['months', 'water', 'free', 'system', 'rusts', 'conditioner', 'less', 'month', 'drain', 'filled', 'rusty', 'water', 'large', 'chunks', 'rust', 'pros', 'cools', 'room', 'well.', 'cons', 'drain', 'free', 'still', 'drain', 'system', 'sucks', 'rusts', 'internally', 'quickly', 'makes', 'loud', 'pulsing', 'gets', 'temp', 'loud', 'pulsing', 'easily', 'wake', 'price', 'water', 'free', 'stated', 'rust', 'good', 'breathing'], tags=[1]),
#  TaggedDocument(words=['love', 'love', 'love', 'deodorant', 'smells', 'amazing', 'says', 'goes', 'keeps', 'incident', 'underarm', 'sweat', 'rings', 'tops', 'dresses', 'blown', 'away', 'best', 'market', 'brands', 'take', 'note', 'shelf'], tags=[1]),
#  TaggedDocument(words=['love', 'product', 'makes', 'homemade', 'cream', 'extravagant'], tags=[0]),
#  TaggedDocument(words=['thankfully', 'liked', 'much'], tags=[0]),
#  TaggedDocument(words=['never', 'used', 'diffuser', 'easy', 'clear', 'light', 'function', 'great', 'chosen', 'colour', 'light', 'alternating'], tags=[1]),
#  TaggedDocument(words=['feel', 'hair', 'gets', 'combed', 'well', 'deep', 'enough', 'like'], tags=[0]),
#  TaggedDocument(words=['gave', 'review', 'three', 'stars', 'shaver', 'barely', 'poodle', 'hair', 'clippers', 'horrible', 'quality', 'also', 'would', 'fall', 'clippers', 'loud', 'dogs', 'groomed', 'terrified'], tags=[0]),
#  TaggedDocument(words=['good', 'quality'], tags=[0]),
#  TaggedDocument(words=['extra', 'virgin', 'coconut', 'jamaica', 'works', 'better'], tags=[0]),
#  TaggedDocument(words=['wife', 'loves'], tags=[0]),
#  TaggedDocument(words=['beautiful', 'comforter', 'well', 'made', 'warm', 'soft', 'bought', 'purple', 'amazing'], tags=[0]),
#  TaggedDocument(words=['exactly', 'needed', 'complicated', 'install', 'window', 'take', 'casing', 'screw', 'casing', 'window', 'attach', 'brackets', 'casing', 'slide', 'unit', 'back', 'casing', 'back', 'together', 'brackets', 'pain', 'thought', 'someone', 'else', 'problem', 'solution', 'already', 'research', 'came', 'across', 'product.', 'caveat.', 'sure', 'check', 'emails', 'contacting', 'confirm', 'type', 'size', 'windows', 'recommend', 'putting', 'information', 'product', 'description', 'three', 'poor', 'review', 'across', 'buried', 'emails', 'inbox', 'connected', 'ernie', 'great', 'even', 'sent', 'overnight', 'regular', 'shipping', 'charge', 'first', 'miffed', 'already', 'read', 'already', 'measured', 'windows', 'second', 'thought', 'pleased', 'much', 'trouble', 'ensure', 'correct', 'type', 'windows', 'people', 'read', 'details.', 'product', 'product', 'sturdy', 'well', 'made', 'extremely', 'easy', 'together', 'simple', 'adjust', 'arms', 'rest', 'inside', 'window', 'frame', 'legs', 'rest', 'outside', 'wall', 'weight', 'unit', 'holds', 'everything', 'sturdily', 'place', 'absolutely', 'ideal', 'upstairs', 'window', 'rental', 'apartment', 'window', 'screws', 'house', 'first', 'floor', 'hesitant', 'unit', 'heavy', 'well', 'thought', 'product', 'recommend', 'correct', 'type', 'size', 'window'], tags=[1]),
#  TaggedDocument(words=['perfect'], tags=[0]),
#  TaggedDocument(words=['excellent', 'leaks'], tags=[0]),
#  TaggedDocument(words=['great'], tags=[0]),
#  TaggedDocument(words=['love', 'colors', 'love', 'timely', 'manner', 'arrived'], tags=[0]),
#  TaggedDocument(words=['awesome', 'knife', 'money', 'mechanism', 'little', 'stiff', 'first', 'loosened', 'lockup', 'solid', 'expect', 'knife', 'knife', 'also', 'useable'], tags=[1]),
#  TaggedDocument(words=['good', 'highly', 'recommended'], tags=[1]),
#  TaggedDocument(words=['great', 'support', 'elbow', 'sleeve.', 'actually', 'wearing', 'tommy', 'copper', 'have.', 'help', 'golfers', 'elbow', 'pain'], tags=[1]),
#  TaggedDocument(words=['cute', 'easy', 'change', 'samsung', 'gearfit', 'well', 'recommend', 'buying', 'little', 'silicone', 'straps', 'band', 'keep', 'coming', 'open', 'fastener', 'good', 'quality', 'original', 'gearfit', 'band', 'come', 'unhooked', 'easily'], tags=[0]),
#  TaggedDocument(words=['cats', 'love', 'third', 'thinks', 'real', 'runs', 'also', 'think', 'real', 'chase', 'ears', 'smile'], tags=[0]),
#  TaggedDocument(words=['beautiful', 'wash', 'asap', 'stinks'], tags=[0]),
#  TaggedDocument(words=['block', 'light', 'much', 'hoped', 'otherwise', 'nice', 'quality', 'fabric', 'good', 'color', 'well', 'made'], tags=[0]),
#  TaggedDocument(words=['curtains', 'perfect', 'room', 'great', 'material', 'room', 'pitch', 'black', 'keeping', 'waking', 'comes', 'would', 'purchase', 'another', 'room', 'house'], tags=[0]),
#  TaggedDocument(words=['firm', 'hurts', 'good'], tags=[0]),
#  TaggedDocument(words=['good'], tags=[0]),
#  TaggedDocument(words=['colitis', 'forti', 'flora', 'probiotic', 'prescribed', 'decided', 'give', 'product', 'wonderful', 'reviews', 'received', 'long', 'would', 'cheaper', 'recently', 'switched', 'hospital', 'almost', '1,000', 'bill', 'almost', 'died', 'talked', 'said', 'flare', 'switching', 'probiotics', 'stopped', 'eating', 'switched', 'product', 'suffering', 'would', 'recommend', 'product', 'anyone', 'severe', 'issues'], tags=[0]),
#  TaggedDocument(words=['seems', 'good', 'cream', 'creams', 'work', 'really'], tags=[0]),
#  TaggedDocument(words=['thanks', 'great', 'seller', 'average', 'product', 'customer', 'service', 'love', 'dropper', 'came', 'essential', 'makes', 'dispensing', 'much', 'easier', 'seller', 'contacted', 'make', 'sure', 'service', 'also', 'happened', 'best', 'deal', 'win-win', 'around'], tags=[0]),
#  TaggedDocument(words=['heavy', 'operate', 'wife'], tags=[1]),
#  TaggedDocument(words=['tried', 'fiber', 'mascara', 'today', 'first', 'time', 'shocked', 'long', 'natural', 'lashes', 'looked', 'given', 'wearing', 'mascara', 'lashes', 'short', 'blonde', 'invisible', 'still', 'getting', 'used', 'dramatic', 'difference', 'long', 'lush', 'false', 'much', 'trouble', 'gives', 'effect', 'although', 'still', 'tweaking', 'real', 'surprise', 'works', 'lower', 'lashes', 'lashes', 'look', 'natural', 'least', 'fake', 'love', 'stuff', 'check', 'back', 'couple', 'tries'], tags=[1]),
#  TaggedDocument(words=['edges', 'tape', 'fray'], tags=[0]),
#  TaggedDocument(words=['good', 'light', 'compression', 'sure', 'much', 'benefit', 'copper', 'compression', 'knee', 'feeling', 'better', 'slowly', 'hurt', 'running', 'hoping', 'helps', 'speed', 'healing', 'process'], tags=[0]),
#  TaggedDocument(words=['scared', 'clacker', 'could', 'blow', 'whistle', 'loud', 'laying', 'would', 'cost', 'much', 'postage', 'send', 'back', 'things', 'ordered', 'looked', 'like', 'would', 'work'], tags=[0]),
#  TaggedDocument(words=['housekeeper', 'recommend', 'product', 'lab/chow', 'problems', 'walking', 'getting', 'forewarned', 'give', 'time', 'work', 'least', 'notice', 'difference', 'easier', 'days', 'seems', 'walking', 'better', 'improved', 'would', 'least', 'acceptable', 'wanted', 'find', 'something', 'natural', 'give', 'helps', 'likes', 'taste', 'sprinkle', 'food', 'best', 'food', 'gets', 'powder', 'sprinkle', 'kibble', 'waste', 'product'], tags=[1]),
#  TaggedDocument(words=['nice'], tags=[0]),
#  TaggedDocument(words=['love', 'fireplace', 'wish', 'larger', 'great', 'addition'], tags=[0]),
#  TaggedDocument(words=['pumps', 'awesome', 'combo', 'castile', 'soap', 'aloe', 'produces', 'creamy', 'foaming', 'soap', 'drying', 'skin'], tags=[1]),
#  TaggedDocument(words=['clock', 'functions', 'excellent', 'perfect', 'bracelet', 'perfect', 'sleeping', 'hurt', 'beyond', 'beautiful'], tags=[0]),
#  TaggedDocument(words=['awesome', 'first', 'time', 'used', 'knew', 'loved', 'short', 'eyelashes', 'really', 'gave', 'longer', 'lashes', 'easy', 'apply', 'comes', 'want', 'apply', 'morning', 'never', 'tried', 'lashes', 'price', 'wanted', 'hooked', 'would', 'recommend', 'love'], tags=[1]),
#  TaggedDocument(words=['seem', 'work', 'well', 'bought', 'last', 'year', 'year'], tags=[0]),
#  TaggedDocument(words=['alright', 'cheaply', 'made', 'okay', 'price'], tags=[0]),
#  TaggedDocument(words=['great', 'flag'], tags=[0]),
#  TaggedDocument(words=['showed', 'time', 'advertised', 'good', 'product', 'good', 'price', 'thank'], tags=[1]),
#  TaggedDocument(words=['need'], tags=[0]),
#  TaggedDocument(words=['jerky', 'would', 'company', 'like', 'things', 'every', 'company', 'make', 'product', 'little', 'different', 'jerky', 'different', 'teriyaki', 'flavor', 'tasted', 'thick', 'coating', 'flavor', 'pieces', 'meat', 'almost', 'like', 'flavored', 'dried', 'weird', 'none', 'pieces', 'meat', 'inches', 'long', 'lots', 'meat', 'crumbs..', 'course', 'bought', 'pound', 'party', 'mistake.', 'advice', 'product..', 'less', 'powder', 'seasoning', 'little', 'spice'], tags=[1]),
#  TaggedDocument(words=['great', 'around', 'glove', 'handling', 'grill', 'grates', 'oven', 'grates', 'backing', 'pans', 'anything', 'gets', 'extremely', 'super', 'satisfied', 'believe', 'hold', 'well', 'time', 'recommend'], tags=[0]),
#  TaggedDocument(words=['great', 'cream'], tags=[0]),
#  TaggedDocument(words=['topper', 'camper.', 'love', 'gives', 'great', 'nights', 'sleep'], tags=[0]),
#  TaggedDocument(words=['love', 'it-my', 'skin', 'clearing', 'taste', 'better', 'mixed', 'pricey', 'clear', 'glowing', 'skin', 'worth', 'price', 'update', 'second', 'beauty', 'dust', 'still', 'glowing'], tags=[0]),
#  TaggedDocument(words=['update', 'contacted', 'company', 'issues', 'quickly', 'refunded', 'money', 'therefore', 'changed', 'stars', 'possible', 'band', 'defective', 'band', 'works', 'fine', 'properly', 'sync', 'phone', 'every', 'restart', 'phone', 'recognize', 'band', 'also', 'example', 'wednesday', 'showing', 'stats', 'thursday', 'going', 'return', 'refund', 'since', 'work', 'correctly', 'would', 'recommend', 'even', 'chancing', 'little', 'better', 'option'], tags=[1]),
#  TaggedDocument(words=['beautiful', 'tapestry', 'true', 'color', 'white', 'pink', 'came', 'much', 'yellow', 'would', 'recommend', 'buying', 'decorations', 'room', 'avoid', 'change', 'things', 'match'], tags=[0]),
#  TaggedDocument(words=['good'], tags=[0]),
#  TaggedDocument(words=['arrived', 'time', 'stitching', 'holds', 'fabric', 'rubber', 'brush', 'coming', 'undone', 'ever', 'tried'], tags=[1]),
#  TaggedDocument(words=['great', 'boat', 'deck', 'comfort', 'cushion', 'keep', 'cool', 'stick', 'deck', 'keeps', 'back', 'getting', 'also'], tags=[0]),
#  TaggedDocument(words=['best', 'tool', 'ever', 'like', 'many', 'others', 'heels', 'crack', 'matter', 'regular', 'pedicures', 'ordered', 'simply', 'amazed', 'results', 'quick', 'painless', 'feet', 'look', 'better', 'years', 'minimal', 'effort'], tags=[0]),
#  TaggedDocument(words=['thing', 'cats', 'still', 'fleas'], tags=[1]),
#  TaggedDocument(words=['best', 'pricing', 'found', 'doggys', 'favorite', 'treats', 'keep', 'buying', 'amazon'], tags=[0]),
#  TaggedDocument(words=['runner', 'bought', 'belt', 'shorter', 'runs', 'miles', 'need', 'wear', 'water', 'belt', 'nice', 'belt', 'fits', 'well', 'however', 'slide', 'rather', 'annoying', 'therefore', 'giving', 'stars', 'instead', 'wish', 'could', 'find', 'belt', 'shift', 'much'], tags=[0]),
#  TaggedDocument(words=['listed'], tags=[0]),
#  TaggedDocument(words=['small', 'head'], tags=[0]),
#  TaggedDocument(words=['pure', 'tree', 'advertised', 'great', 'bottle', 'really', 'good', 'price', 'husband', 'treat', 'different', 'skin', 'issues', 'treates', 'well', 'also', 'make', 'vinegar', 'based', 'household', 'cleaning', 'products', 'splash', 'tree', 'always', 'makes', 'smell', 'clean', 'refreshing', 'helps', 'hide', 'vinegar'], tags=[0]),
#  TaggedDocument(words=['nice', 'happy', 'components', 'however', 'matcha', 'comes', 'even', 'remotely', 'drinkable', 'compared', 'bright', 'vibrant', 'greens', 'matcha', 'barely', 'shade', 'green', 'color', 'resembles', 'brown', 'depth', 'flavor', 'rancid', 'gross'], tags=[1]),
#  TaggedDocument(words=['waste', 'money', 'work', 'back', 'strapes', 'seems', 'flimsy', 'line', 'good', 'well', 'save', 'money', 'better', 'quality'], tags=[1]),
#  TaggedDocument(words=['fits', 'good', 'finish', 'light', 'weight', 'great', 'item'], tags=[0]),
#  TaggedDocument(words=['waste', 'money', 'every', 'single', 'roller', 'defective', 'stay', 'holder', 'turning', 'upside'], tags=[0]),
#  TaggedDocument(words=['excellent', 'flavored', 'coffee', 'love', 'banana'], tags=[1]),
#  TaggedDocument(words=['long', 'enough', 'full', 'effects', 'feel', 'though', 'working', 'nicely'], tags=[1]),
#  TaggedDocument(words=['long', 'take', 'start', 'working', 'using', 'week', 'still', 'getting', 'lots', 'cystic', 'acne'], tags=[1]),
#  TaggedDocument(words=['broken', 'arrived'], tags=[0]),
# ...
#  TaggedDocument(words=['trying', 'cancel', 'order'], tags=[0]),
#  TaggedDocument(words=['excellent', 'move', 'around', 'sink', 'easy', 'clean', 'dishwasher', 'safe', 'best', 'thing', 'melt', 'little', 'money', 'worth', 'every', 'penny', 'thing', 'comes', 'grey', 'wish', 'made', 'black'], tags=[0]),
#  TaggedDocument(words=['great', 'great', 'price'], tags=[0]),
#  TaggedDocument(words=['great', 'product', 'everything', 'needed'], tags=[0]),
#  TaggedDocument(words=['like'], tags=[0]),
#  TaggedDocument(words=['good'], tags=[0]),
#  TaggedDocument(words=['adorable', 'dish', 'towels', 'well', 'made'], tags=[1]),
#  TaggedDocument(words=['concerned', 'find', 'medication', 'original', 'sentry', 'stopped', 'production', 'fritz', 'stepped', 'mardel', 'maracyn', 'minocycline', 'many', 'aquarium', 'medication', 'staples', 'many', 'relied', 'many', 'years', 'includes', 'maracyn', 'clout', 'maroxy', 'coppersafe', 'many', 'others', 'sentry', 'antibiotic', 'minocycline', 'form', 'mardel', 'maracyn', 'effective', 'treatment', 'found', 'popeye', 'bacterial', 'disease', 'causes', 'internal', 'swelling', 'fish', 'results', 'gradual', 'enlargement', 'swelling', 'eyes', 'result', 'popeye', 'condition', 'usually', 'fatal', 'treated', 'product', 'loss', 'treatment', 'condition', 'effective', 'minocycline', 'found', 'maracyn', 'looked', 'medication', 'internet', 'without', 'success', 'market', 'opportunity', 'presented', 'sentry', 'withdrawal', 'fritz', 'marketing', 'products', 'addition', 'products', 'almost', 'exactly', 'packaging', 'graphics', 'products', 'presented', 'previous', 'albeit', 'addition', 'fritz', 'imprint', 'next', 'product', 'line', 'name', 'helps', 'already', 'familiar', 'product', 'browsing', 'internet', 'initially', 'little', 'confused', 'thought', 'might', 'looking', 'pages', 'products', 'longer', 'available', 'unavailable', 'year', 'said', 'past', 'brief', 'confusion', 'glad', 'many', 'fine', 'mardel', 'products', 'commonly', 'available', 'vast', 'number', 'tropical', 'fish', 'hobbyists', 'need', 'tried', 'tested', 'medications', 'treat', 'fish'], tags=[1]),
#  TaggedDocument(words=['used', 'soleil', 'venus', 'embrace', 'razors', 'schick', 'beats', 'landslide.', 'little', 'trimmer', 'quite', 'cool', 'definitely', 'made', 'easier', 'shaving', 'less', 'ingrown', 'hair', 'load', 'battery', 'press', 'button', 'activates', 'need', 'hold', 'button.', 'razor', 'great', 'minimal', 'irritation', 'razor', 'bumps', 'using', 'normally', 'irritation', 'pretty', 'extreme', 'lotion', 'activates', 'submerge', 'razor', 'water', 'uses', 'still', 'feel', 'lotion', 'nice', 'schick', 'recommends', 'razor', 'skintimate', 'shave', 'cream', 'agree', 'tried', 'aveeno', 'seemed', 'clog', 'razor', 'little'], tags=[0]),
#  TaggedDocument(words=['knofe', 'functions', 'well.the', 'blade', 'little', 'thin', 'liking', 'seems', 'stand', 'ever', 'challenge', 'faced'], tags=[0]),
#  TaggedDocument(words=['growing', 'nicely', 'love'], tags=[1]),
#  TaggedDocument(words=['great', 'lots', 'pockets', 'store', 'snacks', 'tees', 'balls'], tags=[0]),
#  TaggedDocument(words=['similar', 'ofher', 'grips', 'difference', 'easily', 'overcome', 'work', 'well', 'good', 'value', 'easily', 'recommend', 'others'], tags=[0]),
#  TaggedDocument(words=['happy', 'pieces', 'small', 'bull', 'parts', 'private', 'parts', 'like', 'smell', 'worse', 'throw', 'away'], tags=[1]),
#  TaggedDocument(words=['love', 'wish', 'expensive', 'would', 'like', 'stock', 'like', 'boys'], tags=[0]),
#  TaggedDocument(words=['units', 'function', 'together', 'words', 'work'], tags=[1]),
#  TaggedDocument(words=['started', 'rusting', 'immediately'], tags=[1]),
#  TaggedDocument(words=['still', 'lying', 'flat', 'floor', 'understand', 'things', 'come'], tags=[0]),
#  TaggedDocument(words=['like'], tags=[0]),
#  TaggedDocument(words=['came', 'sooner', 'expected', 'sized', 'perfectly', 'cards', 'come', 'handy', 'already'], tags=[1]),
#  TaggedDocument(words=['excellent', 'service', 'quality'], tags=[0]),
#  TaggedDocument(words=['bother', 'buying', 'seen', 'better', 'stuff', 'gumball', 'machine'], tags=[1]),
#  TaggedDocument(words=['fits', 'perfectly', 'sofa', 'loves'], tags=[1]),
#  TaggedDocument(words=['takes', 'time', 'dryer', 'soft', 'touch'], tags=[0]),
#  TaggedDocument(words=['product', 'make', 'tempurpedic', 'mattress', 'cooler', 'comfortable', 'addition', 'product', 'nicely', 'packed', 'odor', 'highly', 'recommend', 'mattress', 'memory', 'form', 'mattress', 'owners'], tags=[0]),
#  TaggedDocument(words=['simple', 'effective', 'cleaning', 'small', 'pond', 'fish', 'tank', 'mainly', 'removing', 'water', 'deck', 'pond', 'would', 'like', 'longer', 'flow', 'tube', 'used', 'several', 'times', 'long', 'range', 'durability', 'unknown', 'given', 'simplicity', 'suspect', 'last', 'long', 'time', 'would', 'recommend', 'siphon', 'price', 'point', 'good'], tags=[0]),
#  TaggedDocument(words=['little', 'perfect', 'carry', 'oils', 'purse', 'works', 'described'], tags=[0]),
#  TaggedDocument(words=['good', 'hepa', 'filter', 'helps', 'asthma', 'dust', 'ring', 'front', 'develops', 'ionizer', 'working'], tags=[1]),
#  TaggedDocument(words=['product', 'wear', 'away', 'quickly'], tags=[0]),
#  TaggedDocument(words=['refreshing', 'eric', 'wong', 'things', 'together', 'cage', 'cardio', 'fight', 'deck.', 'something', 'anyone', 'looking', 'great', 'workout', 'routine', 'together', 'reason', 'fitness', 'karate', 'enjoy', 'deck'], tags=[0]),
#  TaggedDocument(words=['upon', 'taking', 'found', 'relatively', 'easy', 'assemble', 'little', 'tweaking', 'found', 'decent', 'accuracy', 'department', 'think', 'would', 'accurate', 'three', 'vanes', 'bolts', 'instead', 'great', 'shooting', 'especially', 'price'], tags=[0]),
#  TaggedDocument(words=['great', 'baskets', 'great', 'price', 'hold', 'anticipated', 'sturdy', 'nice', 'neutral', 'color'], tags=[0]),
#  TaggedDocument(words=['wrong', 'color', 'received', 'purple', 'blue'], tags=[0]),
#  TaggedDocument(words=['ordered', 'throw', 'reading', 'lots', 'positive', 'reviews', 'dismay', 'quickly', 'discovered', 'blanket', 'tassels', 'sheds', 'small', 'fibers', 'looks', 'nice', 'move', 'around', 'much', 'otherwise', 'shed', 'everywhere'], tags=[1]),
#  TaggedDocument(words=['works', 'great'], tags=[0]),
#  TaggedDocument(words=['fantastic', 'pain', 'knees', 'gone', 'couple', 'hours', 'wore', 'work', 'weeks', 'knees', 'felt', 'great', 'worn', 'week', 'knees', 'still', 'great'], tags=[1]),
#  TaggedDocument(words=[], tags=[0]),
#  TaggedDocument(words=['dentist', 'recommended', 'using', 'baking', 'soda', 'toothpaste', 'plaque', 'builds', 'rather', 'quickly', 'cleanings', 'noticed', 'difference', 'build', 'lower', 'teeth', 'since', 'using', 'product', 'noticed', 'difference', 'whitening', 'though', 'overall', 'smell', 'nice', 'foams', 'quickly', 'seems', 'help', 'plaque', 'continue'], tags=[1]),
#  TaggedDocument(words=['worked', 'weeks', 'helped', 'problem', 'kill', 'every', 'flea', 'last', 'month', 'shell', 'money', 'advantage', 'frontline', 'save', 'hassle'], tags=[0]),
#  TaggedDocument(words=['love', 'love', 'love', 'yoga', 'alot', 'research', 'deciding', 'getting', 'yoga', 'addict', 'yoga', 'long', 'zipper', 'end-to', 'makes', 'putting', 'taking', 'easy', 'external', 'pouch', 'perfect', 'trinkets', 'ventilation', 'slots', 'great', 'addition', 'well', 'constructed', 'sturdy', 'definitely', 'getting', 'monies', 'worth', 'best', 'part', 'though', 'personal', 'message', 'received', 'richee', 'really', 'goes', 'along', 'instead', 'getting', 'automatic', 'electronic', 'response', 'really', 'appreciated', 'shopping', 'yoga', 'look', 'best', 'namaste'], tags=[1]),
#  TaggedDocument(words=['work', 'waste', 'money', 'bought', 'little', 'vials'], tags=[1]),
#  TaggedDocument(words=['item', 'meet', 'importantly', 'clasps', 'tightly', 'clamped', 'hook', 'despite', 'taken', 'according', 'fitting', 'accurate'], tags=[0]),
#  TaggedDocument(words=['hate', 'smell', 'burns'], tags=[0]),
#  TaggedDocument(words=['love', 'ursula', 'soon', 'fast', 'loved', 'much', 'bought', 'sister', 'followed', 'size', 'fits', 'perfectly', 'little', 'perfect', 'feel', 'like', 'could', 'little', 'tighter', 'ordering', 'size', 'smaller', 'waist', 'measures', '34.5', 'ordered', 'long'], tags=[1]),
#  TaggedDocument(words=['using', 'brand', 'lavender', 'long', 'took', 'shaming', 'almost', 'full', 'bottle', 'ground', 'order', 'online', 'glad', 'really', 'like', 'especially', 'pipet', 'smells', 'lovely', 'slightly', "'perfumey", 'brand', 'still', 'nice', 'smells', 'lighter', 'almost', 'lacking', 'lavender', "'straight", 'leaf', 'plant', 'strong', 'oily', 'smell', 'think.', 'order', 'lavender', 'religiously'], tags=[0]),
#  TaggedDocument(words=['used', 'grow', 'plants', 'works', 'better', 'costs', 'much', 'plant', 'plant', 'come', 'back', 'next', 'year', 'lasts', 'bottle', 'seasons'], tags=[1]),
#  TaggedDocument(words=['works', 'great', 'pugs', 'chase', 'want', 'come', 'called', 'outside', 'easy', 'vibrate', 'tone', 'shock', 'choices', 'correct', 'lowest', 'settings', 'without', 'hurting', 'freaking'], tags=[1]),
#  TaggedDocument(words=['nice', 'works', 'well', 'keeps', 'skin', 'soft'], tags=[0]),
#  TaggedDocument(words=['great'], tags=[0]),
#  TaggedDocument(words=['looked', 'everywhere', 'beanie', 'absolutely', 'love', 'favorite', 'hands', 'super', 'warm', 'fleece', 'lining', 'wore', 'game', 'green', 'warm', 'glad', 'able', 'find', 'last', 'minute', 'official', 'sideline', 'beanie', 'sold', 'everywhere', 'else', 'looked', 'cowboys'], tags=[1]),
#  TaggedDocument(words=['sheets', 'surpassed', 'used', 'cheap', 'ones', 'walmart', 'love', 'feel', 'deep', 'pocket', 'mattress'], tags=[1]),
#  TaggedDocument(words=['stuff', 'ramen', 'every', 'coconut', 'milk', 'baby', 'spinach', 'mushrooms', 'watercress', 'sauce', 'sauce', 'recipe', 'make', 'loose', 'spin-off', 'gordon', 'ramsay', 'one..', 'never', 'tired', 'love'], tags=[1]),
#  TaggedDocument(words=['great'], tags=[0]),
#  TaggedDocument(words=['good', 'price', 'large', 'size', 'smells', 'great'], tags=[0]),
#  TaggedDocument(words=['great', 'stealthy', 'cooler', 'course', 'fits', 'kept', 'soda', 'cool', 'thru', 'holes', 'great', 'product', 'family', 'business', 'highly', 'recommended'], tags=[0]),
#  TaggedDocument(words=['things', 'amazing.', 'heels', 'hurt', 'constant', 'basis', 'pain', 'much', 'could', 'barely', 'walk', 'wore', 'three', 'days', 'vacationing', 'feet', 'hurt', 'throughout', 'like', 'normally', 'would.', 'help', 'long', 'term', 'happy', 'purchase', 'heels', 'hurt'], tags=[0]),
#  TaggedDocument(words=['effective', 'safe', 'make', 'remover', 'clears', 'shadow', 'foundation', 'others', 'little', 'sponge', 'shower', 'remove', 'washes', 'face', 'cleanser', 'face', 'looks', 'clean'], tags=[0]),
#  TaggedDocument(words=['thought', 'glasses', 'arrived'], tags=[0]),
#  TaggedDocument(words=['tablets', 'really', 'able', 'take'], tags=[0]),
#  TaggedDocument(words=['love', 'arrived', 'pretty', 'quickly', 'colors', 'rich', 'bold', 'scent', 'care', 'course', 'dries', 'lips', 'matte', 'lipstick', 'hands', 'love', 'getting', 'colors'], tags=[0]),
#  TaggedDocument(words=['really', 'liked', 'balls', 'purchased', 'team', 'noticed', 'weeks', 'leaks', 'need', 'keep', 'pump', 'handy', 'keep', 'inflated', 'right', 'level'], tags=[0]),
#  TaggedDocument(words=['absolutely', 'beautiful', 'feels', 'luxurious', 'actually', 'flipped', 'used', 'side', 'want', 'black', 'trim', 'beautiful', 'could', 'pleased', 'purchase', 'warning', 'zipper', 'hard', 'find', 'located', 'duvet', 'cover', 'middle'], tags=[1]),
#  TaggedDocument(words=['always', 'love'], tags=[0]),
#  TaggedDocument(words=['bought', 'many', 'wall', 'mount', 'fruit', 'baskets', 'made', 'great', 'quality', 'keeps', 'items', 'organized', 'adds', 'great', 'decor', 'kitchen'], tags=[0]),
#  TaggedDocument(words=['perfect', 'size', 'cosmetics', 'looks', 'beautiful', 'counter', 'leaves', 'room', 'decorative', 'objects', 'long', 'counter', 'like', 'less', 'display', 'perfect'], tags=[1]),
#  TaggedDocument(words=['great', 'finally', 'dark', 'room', 'sleep', 'color', 'green', 'darken', 'person', 'still', 'love'], tags=[1]),
#  TaggedDocument(words=['like', 'much', 'sent', 'another', 'pair', 'work', 'retail', 'feet', 'tile', 'floor', '8-10', 'hours', 'really', 'help', 'prevent', 'pain', 'tiredness', 'feet', 'legs', 'coworkers'], tags=[0]),
#  TaggedDocument(words=['excellent', 'product'], tags=[0]),
#  TaggedDocument(words=['wonderful', 'sharp', 'blades'], tags=[1]),
#  TaggedDocument(words=['pretty', 'glams', 'fitbit', 'perfectly', 'right', 'size', 'small'], tags=[0]),
#  TaggedDocument(words=['results', 'product', 'followed', 'directions', 'minimal', 'results'], tags=[1]),
#  TaggedDocument(words=['using', 'product', 'days', 'difference', 'skin', 'already', '..it', 'great'], tags=[0]),
#  TaggedDocument(words=['great', 'wall', 'effect'], tags=[0]),
#  TaggedDocument(words=['loves', 'treat', 'great', 'size', 'training', 'would', 'recommend', 'purchase'], tags=[0]),
#  TaggedDocument(words=['works', 'really', 'well', 'good', 'sale'], tags=[0]),
#  TaggedDocument(words=['mine', 'fine', 'like', 'feel', 'cool', 'dont', 'know', 'dont', 'shave', 'legs', 'seem', 'little', 'irritating', '3hrs'], tags=[0]),
#  TaggedDocument(words=['great', 'stuff'], tags=[1]),
#  TaggedDocument(words=['love', 'outcome', 'leaves', 'tattoo', 'confirm', 'definition'], tags=[0]),
#  TaggedDocument(words=['product', 'best', 'thing', 'since', 'scoopable', 'kitty', 'litter', 'somewhat', 'skittish', 'kitty', 'took', 'extra', 'steps', 'used', 'movement', 'able', 'training', 'process', 'less', 'weeks', 'charlie', 'happy', 'kitty', 'deal', 'second', 'kitty', 'eating', 'food', 'gets', 'wonderful', 'product'], tags=[0]),
#  TaggedDocument(words=['first', 'time', 'user', 'worked', 'great', 'read', 'file', 'direction', 'another', 'review', 'works', 'well', 'metal', 'filer', 'without', 'burnt', 'smell', 'sometimes', 'lingers', 'filing', 'long'], tags=[0]),
#  TaggedDocument(words=['really', 'really', 'nice', 'jump', 'ropes', 'beautifully', 'made', 'strong', 'adjusted', 'popping', 'piece', 'cutting', 'height', 'boys', 'love', 'daily', 'holding', 'great'], tags=[1]),
#  TaggedDocument(words=['product', 'smoothly', 'cover', 'anything', 'watery'], tags=[1]),
#  TaggedDocument(words=['always', 'corsets', 'waist', 'shapers', 'also', 'known', 'waist', 'trainers', 'since', '2003', 'tried', 'every', 'shaper', 'waist', 'trainer', 'particular', 'kind', 'usually', 'give', 'product', 'chance', 'opinions', 'medium', 'long', 'ursula', 'waist', 'trainer', 'awesome', 'comfortable', 'enough', 'wear', 'including', 'intense', 'workout', 'session', 'purchased', 'long', 'already', 'hook', 'wash', 'daily', 'workout', 'sessions', 'everyday', 'note', 'trainer', 'dryer', 'wash', 'hang', 'hooks', 'really', 'messed', 'dryer', 'stupid', 'well', 'worth', 'purchase', 'another', 'worried'], tags=[1]),
#  TaggedDocument(words=['great', 'back', 'knees', 'like', 'much'], tags=[0]),
#  TaggedDocument(words=['purchased', 'library', 'baby', 'shower', 'invites', 'self', 'adhesive', 'easy', 'print', 'well', 'done'], tags=[1]),
#  TaggedDocument(words=['perfect'], tags=[0]),
#  TaggedDocument(words=['enough', 'good', 'things', 'soap', 'skin', 'feels', 'great', 'using', 'also', 'washing', 'hair', 'soap', 'several', 'years', 'best', 'smell', 'soap', 'also', 'delightful', 'definitely'], tags=[1]),
#  TaggedDocument(words=['useful', 'inexpensive'], tags=[0]),
#  TaggedDocument(words=['awful', 'came', 'days', 'peeled', 'whole', 'thing', 'looking', 'better', 'brand'], tags=[0]),
#  TaggedDocument(words=['great'], tags=[0]),
#  TaggedDocument(words=['fits', 'bats', 'helmet', 'cleats', 'practice', 'balls', 'definitely', 'enough', 'light', 'enough', 'year', 'carry'], tags=[1]),
#  TaggedDocument(words=['work', 'fine', 'exactly', 'described', 'however', 'find', 'easier', 'finger', 'brush', 'dogs', 'dogs', 'chew', 'long', 'handles', 'brushing', 'teeth', 'issue', 'product', 'behavior', 'using', 'brushes'], tags=[0]),
#  ...]

# %%
import multiprocessing

# %%
from tqdm import tqdm

# %%
cores = multiprocessing.cpu_count()

# %%
model_dbow = Doc2Vec(dm=1, vector_size=25, negative=5, hs=0, min_count=2, sample = 0, workers=cores, alpha=0.025, min_alpha=0.001)

# %%
model_dbow.build_vocab(tagged_data)

# %%
model_dbow.train(tagged_data,total_examples=len(tagged_data), epochs=30)

# %%
model_dbow.save('d2v_25.model')

# %%
m=gensim.models.Doc2Vec.load("d2v_25.model")

# %%
start_alpha=0.01
infer_epoch=50
X=[]
for d in cleaned_review:
     
    X.append( m.infer_vector(d, alpha=start_alpha, steps=infer_epoch) )

# %%
import numpy as np
np.size(X,1)
# Out:
# 25

# %%
X_df=pd.DataFrame(X)

# %%
X_df.to_csv('X_df.csv')

# %%
X_df=pd.read_csv('X_df.csv')

# %%
X_df=X_df.drop(['Unnamed: 0'],axis=1)

# %%
from sklearn.cluster import KMeans

# %%
kmean = KMeans(n_clusters=25, random_state=0)
kmean_cluster=kmean.fit(X)

# %%
df['clusters']=kmean_cluster.labels_

# %%
df[['clusters']]
# Out:
#         clusters
# 0              8
# 1             20
# 2              1
# 3             22
# 4             10
# ...          ...
# 247710         5
# 247711        13
# 247712         2
# 247713        24
# 247714         4
#
# [247715 rows x 1 columns]

# %%
for epoch in range(max_epochs):
    print('iteration {0}'.format(epoch))
    model.train(tagged_data,
                total_examples=model.corpus_count,
                epochs=model.iter)
    # decrease the learning rate
    model.alpha -= 0.0002
    # fix the learning rate, no decay
    model.min_alpha = model.alpha

model.save("d2v.model")
print("Model Saved")
# Out:
# iteration 0
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `iter` (Attribute will be removed in 4.0.0, use self.epochs instead).
#   """
# iteration 1
# iteration 2
# iteration 3
# iteration 4
# iteration 5
# iteration 6
# iteration 7
# iteration 8
# iteration 9
# iteration 10
# iteration 11
# iteration 12
# iteration 13
# iteration 14
# iteration 15
# iteration 16
# iteration 17
# iteration 18
# iteration 19
# iteration 20
# iteration 21
# iteration 22
# iteration 23
# iteration 24
# iteration 25
# iteration 26
# iteration 27
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-109-cdd4cef430db> in <module>()
#       3     model.train(tagged_data,
#       4                 total_examples=model.corpus_count,
# ----> 5                 epochs=model.iter)
#       6     # decrease the learning rate
#       7     model.alpha -= 0.0002
#
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\models\doc2vec.py in train(self, documents, corpus_file, total_examples, total_words, epochs, start_alpha, end_alpha, word_count, queue_factor, report_delay, callbacks)
#     555             sentences=documents, corpus_file=corpus_file, total_examples=total_examples, total_words=total_words,
#     556             epochs=epochs, start_alpha=start_alpha, end_alpha=end_alpha, word_count=word_count,
# --> 557             queue_factor=queue_factor, report_delay=report_delay, callbacks=callbacks, **kwargs)
#     558
#     559     @classmethod
#
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\models\base_any2vec.py in train(self, sentences, corpus_file, total_examples, total_words, epochs, start_alpha, end_alpha, word_count, queue_factor, report_delay, compute_loss, callbacks, **kwargs)
#    1065             total_words=total_words, epochs=epochs, start_alpha=start_alpha, end_alpha=end_alpha, word_count=word_count,
#    1066             queue_factor=queue_factor, report_delay=report_delay, compute_loss=compute_loss, callbacks=callbacks,
# -> 1067             **kwargs)
#    1068
#    1069     def _get_job_params(self, cur_epoch):
#
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\models\base_any2vec.py in train(self, data_iterable, corpus_file, epochs, total_examples, total_words, queue_factor, report_delay, callbacks, **kwargs)
#     550                 trained_word_count_epoch, raw_word_count_epoch, job_tally_epoch = self._train_epoch(
#     551                     data_iterable, cur_epoch=cur_epoch, total_examples=total_examples,
# --> 552                     total_words=total_words, queue_factor=queue_factor, report_delay=report_delay)
#     553             else:
#     554                 trained_word_count_epoch, raw_word_count_epoch, job_tally_epoch = self._train_epoch_corpusfile(
#
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\models\base_any2vec.py in _train_epoch(self, data_iterable, cur_epoch, total_examples, total_words, queue_factor, report_delay)
#     486         trained_word_count, raw_word_count, job_tally = self._log_epoch_progress(
#     487             progress_queue, job_queue, cur_epoch=cur_epoch, total_examples=total_examples, total_words=total_words,
# --> 488             report_delay=report_delay, is_corpus_file_mode=False)
#     489
#     490         return trained_word_count, raw_word_count, job_tally
#
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\models\base_any2vec.py in _log_epoch_progress(self, progress_queue, job_queue, cur_epoch, total_examples, total_words, report_delay, is_corpus_file_mode)
#     343
#     344         while unfinished_worker_count > 0:
# --> 345             report = progress_queue.get()  # blocks if workers too slow
#     346             if report is None:  # a thread reporting that it finished
#     347                 unfinished_worker_count -= 1
#
# C:\ProgramData\Anaconda3\lib\queue.py in get(self, block, timeout)
#     162             elif timeout is None:
#     163                 while not self._qsize():
# --> 164                     self.not_empty.wait()
#     165             elif timeout < 0:
#     166                 raise ValueError("'timeout' must be a non-negative number")
#
# C:\ProgramData\Anaconda3\lib\threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:

# %%
def vec_for_learning(model, tagged_docs):
    sents = tagged_docs.values
    targets, regressors = zip(*[(doc.tags[0], model.infer_vector(doc.words, steps=20)) for doc in sents])
    return targets, regressors

# %%
from sklearn.decomposition import LatentDirichletAllocation as LDA
number_topics = 5
number_words = 10

lda = LDA(n_components=number_topics, n_jobs=-1)

# %%
cleaned_review
# Out:
# 0         [love, brushes, soft, foundation, brush, washe...
# 1         [suffer, acne, however, suffer, compulsive, sk...
# 2                                            [great, socks]
# 3         [absolutely, vinyl, assumed, heat, vinyl, coul...
# 4         [these, pliers, great, find, fishermen, they, ...
#                                 ...
# 247710                                  [product, promised]
# 247711    [locks, securely, combo, horrible, bought, mou...
# 247712    [totally, love, last, enjoy, coffee, worry, an...
# 247713    [amazing, smell, arrived, really, satisfied, p...
# 247714    [fits, perfectly, slipping, sweat, great, prod...
# Name: Review_Body, Length: 247715, dtype: object

# %%
dictionary = gensim.corpora.Dictionary(cleaned_review)

# %%
count = 0
for k, v in dictionary.iteritems():
    print(k, v)
    count += 1
    if count > 10:
        break
# Out:
# 0 always
# 1 brush
# 2 brushes
# 3 cosmetic
# 4 eyeliner
# 5 eyeshadow
# 6 foundation
# 7 good
# 8 harsh
# 9 little
# 10 love

# %%
dictionary.filter_extremes(no_below=15, no_above=0.5, keep_n=100000)

# %%
bow_corpus = [dictionary.doc2bow(doc) for doc in cleaned_review]

# %%
lda_model = gensim.models.LdaMulticore(bow_corpus, num_topics=10, id2word=dictionary, passes=2, workers=2)

# %%
lda_model[bow_corpus]

# %%
from sklearn.decomposition import LatentDirichletAllocation
LDA_text = LatentDirichletAllocation(n_components=5, random_state=42)

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(lowercase=True, preprocessor = lambda x: x, tokenizer = lambda
x: x)

# %%
topic_vectorized=vectorizer.fit_transform(cleaned_review).toarray()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-28-74f8906f7f32> in <module>()
# ----> 1 topic_vectorized=vectorizer.fit_transform(cleaned_review).toarray()
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\sparse\compressed.py in toarray(self, order, out)
#    1022         if out is None and order is None:
#    1023             order = self._swap('cf')[0]
# -> 1024         out = self._process_toarray_args(order, out)
#    1025         if not (out.flags.c_contiguous or out.flags.f_contiguous):
#    1026             raise ValueError('Output array must be C or F contiguous')
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\sparse\base.py in _process_toarray_args(self, order, out)
#    1184             return out
#    1185         else:
# -> 1186             return np.zeros(self.shape, dtype=self.dtype, order=order)
#    1187
#    1188
#
# MemoryError: Unable to allocate array with shape (247715, 48602) and data type int64
